# %% [markdown]
# # Bookworm
#
#
# ## Overview
#
# In this project, you will build a simple question-answering agent that is able to learn from any text data you provide, and answer queries posed in natural language. You will use IBM Watson's cloud-based services to process the input text data and find relevant responses.
#
# ## Learning Objectives
#
# By completing this project, you will learn how to:
#
# - Create a cloud-based NLP service instance and configure it.
# - Ingest a set of text documents using the service and analyze the results.
# - Accept questions in natural language and parse them.
# - Find relevant answers from the preprocessed text data.
#
# ## Getting Started
#
# In order to use Watson's cloud-based services, you first need to create an account on the [IBM Bluemix platform](https://console.ng.bluemix.net/).
#
# <div>
#     <div style="display: table-cell; width: 50%;">
#         <img src="images/watson-logo.png" alt="IBM Watson logo" width="200" />
#     </div>
#     <div style="display: table-cell; width: 50%;">
#         <img src="images/bluemix-logo.png" alt="IBM Bluemix logo" width="400" />
#     </div>
# </div>
#
# Then, for each service you want to use, you have to create an instance of that service. You can continue with the tasks below, and create a service instance when indicated.

# %% [markdown]
# ## 1. Create and configure Discovery service
#
# Create an instance of the **Discovery** service. You will use this to process a set of text documents, and _discover_ relevant facts and relationships.
#
# - Go to the [IBM Bluemix Catalog](https://console.ng.bluemix.net/catalog/?taxonomyNavigation=services&category=watson).
# - Select the service you want, **Discovery**, under the **Watson** category.
# - Enter a Service Name for that instance, e.g. **Disco1** and a Credential Name, e.g. **Disco1-Creds** (these are just for you to be able to refer to later, they do not affect the functioning of the service).
# - You should be able to see your newly-created service in your [Services Dashboard](https://console.ng.bluemix.net/dashboard/services).
# - Open the service instance, click on the **Service credentials** tab, and then **View credentials** under Actions. This is where you will find the username and password to use when connecting to the service.
#
# <img src="images/discovery-creds.png" alt="Discovery Service - Credentials tab" width="800" />
#
# Save the credentials for the discovery service in a JSON file in the current directory named `service-credentials.json` with the following format:
#
# ```json
# {
#     "discovery": {
#         "username": "<your Discovery username here>",
#         "password": "<your Discovery password here>"
#     },
#     "conversation": {
#         "username": "",
#         "password": ""
#     }
# }
#
# ```
#
# You will be filling out the Conversation service credentials later, when you create an instance for it. Note that you should keep these credentials secret. Please do not turn them in with your submission!
#
# ### Connect to the service instance
#
# Let's connect to the service instance you just created using IBM Watson's [Python SDK](https://github.com/watson-developer-cloud/python-sdk). You will first need to install the SDK:
# ```bash
# pip install watson-developer-cloud
# ```
#
# Now execute each code cell below using **`Shift+Enter`**, and complete any steps indicated by a **`TODO`** comment. For more information on the Discovery service, please read the [Documentation](https://www.ibm.com/watson/developercloud/doc/discovery/index.html) and look at the [API Reference](https://www.ibm.com/watson/developercloud/discovery/api/v1/?python) as needed.

# %%
# Usual Python imports
import sys
import os
import glob
import json

# BeautifulSoup, for parsing HTML
from bs4 import BeautifulSoup

# Matplotlib, for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# Watson Python SDK
import watson_developer_cloud

# Utility functions
import helper

# %%
# Connect to the Discovery service instance
# TODO: Ensure that your username and password from the Service Credentials tab are in service-credentials.json
# Note that these credentials are different from your IBM Bluemix login, and are specific to the service instance
discovery_creds = helper.fetch_credentials('discovery')
discovery = watson_developer_cloud.DiscoveryV1(
    version='2016-11-07',
    username=discovery_creds['username'],
    password=discovery_creds['password'])

# %% [markdown]
# ### Create an environment
#
# The Discovery service organizes everything needed for a particular application in an _environment_. Let's create one called "Bookworm" for this project.
#
# > _**Note**: It is okay to run this block multiple times - it will not create duplicate environments with the same name._

# %%
# Prepare an environment to work in
env, env_id = helper.fetch_object(
    discovery, "environment", "Bookworm",
    create=True, create_args=dict(
        description="A space to read and understand stories",  # feel free to edit
        size=0  # use 0 for free plan (see API reference for more on sizing)
    ))
print(json.dumps(env, indent=2))
# Out:
# Found environment: Bookworm (9b61b7b2-72cb-4d55-9563-0ba01823ad17)
# {
#   "environment_id": "9b61b7b2-72cb-4d55-9563-0ba01823ad17",
#   "size": 0,
#   "index_capacity": {
#     "memory_usage": {
#       "used_bytes": 765784792,
#       "used": "730.31 MB",
#       "percent_used": 72.5,
#       "total_bytes": 1056309248,
#       "total": "1007.38 MB"
#     },
#     "disk_usage": {
#       "used_bytes": 15660150,
#       "used": "14.93 MB",
#       "percent_used": 0.36,
#       "total_bytes": 4294967296,
#       "total": "4 GB"
#     }
#   },
#   "updated": "2017-06-18T17:02:11.406Z",
#   "name": "Bookworm",
#   "status": "active",
#   "description": "A space to read and understand stories",
#   "read_only": false,
#   "created": "2017-06-18T17:02:11.406Z"
# }

# %% [markdown]
# ### Verify configuration options
#
# A _configuration_ defines what natural language processing routines are applied to any documents that are submitted to the service. Each environment gets a default configuration when it is created.
#
# You can fetch the default configuration and view the different options using the following piece of code.

# %%
# View default configuration
cfg_id = discovery.get_default_configuration_id(environment_id=env_id)
cfg = discovery.get_configuration(environment_id=env_id, configuration_id=cfg_id)
print(json.dumps(cfg, indent=2))
# Out:
# {
#   "normalizations": [],
#   "enrichments": [
#     {
#       "enrichment": "alchemy_language",
#       "source_field": "text",
#       "options": {
#         "extract": "keyword, entity, doc-sentiment, taxonomy, concept, relation",
#         "sentiment": true,
#         "quotations": true
#       },
#       "destination_field": "enriched_text"
#     }
#   ],
#   "configuration_id": "7d6901e3-0d6f-422e-bba8-a428af92f901",
#   "conversions": {
#     "json_normalizations": [],
#     "html": {
#       "exclude_tags_keep_content": [
#         "font",
#         "em",
#         "span"
#       ],
#       "exclude_tag_attributes": [
#         "EVENT_ACTIONS"
#       ],
#       "exclude_tags_completely": [
#         "script",
#         "sup"
#       ],
#       "exclude_content": {
#         "xpaths": []
#       },
#       "keep_content": {
#         "xpaths": []
#       }
#     },
#     "word": {
#       "heading": {
#         "styles": [
#           {
#             "names": [
#               "pullout heading",
#               "pulloutheading",
#               "header"
#             ],
#             "level": 1
#           },
#           {
#             "names": [
#               "subtitle"
#             ],
#             "level": 2
#           }
#         ],
#         "fonts": [
#           {
#             "min_size": 24,
#             "italic": false,
#             "bold": false,
#             "level": 1
#           },
#           {
#             "min_size": 18,
#             "italic": false,
#             "bold": true,
#             "max_size": 23,
#             "level": 2
#           },
#           {
#             "min_size": 14,
#             "italic": false,
#             "bold": false,
#             "max_size": 17,
#             "level": 3
#           },
#           {
#             "min_size": 13,
#             "italic": false,
#             "bold": true,
#             "max_size": 13,
#             "level": 4
#           }
#         ]
#       }
#     },
#     "pdf": {
#       "heading": {
#         "fonts": [
#           {
#             "min_size": 24,
#             "max_size": 80,
#             "level": 1
#           },
#           {
#             "min_size": 18,
#             "italic": false,
#             "bold": false,
#             "max_size": 24,
#             "level": 2
#           },
#           {
#             "min_size": 18,
#             "bold": true,
#             "max_size": 24,
#             "level": 2
#           },
#           {
#             "min_size": 13,
#             "italic": false,
#             "bold": false,
#             "max_size": 18,
#             "level": 3
#           },
#           {
#             "min_size": 13,
#             "bold": true,
#             "max_size": 18,
#             "level": 3
#           },
#           {
#             "min_size": 11,
#             "italic": false,
#             "bold": false,
#             "max_size": 13,
#             "level": 4
#           }
#         ]
#       }
#     }
#   },
#   "updated": "2017-06-18T17:02:11.440Z",
#   "name": "Default Configuration",
#   "description": "The configuration used by default when creating a new collection without specifying a configuration_id.",
#   "created": "2017-06-18T17:02:11.440Z"
# }

# %% [markdown]
# There are 3 main configuration blocks that affect how input documents are processed:
#
# 1. **`conversions`**: How to convert documents in various formats (Word, PDF, HTML) and extract elements that indicate some structure (e.g. headings).
# 2. **`enrichments`**: What NLP output results are we interested in (keywords, entities, sentiment, etc.).
# 3. **`normalizations`**: Post-processing steps to be applied to the output. This can be left empty in most cases, unless you need the output to be normalized into a very specific format.
#
# _**Note**: The default configuration for an environment cannot be modified. If you need to change any of the options, you will need to create a new one, and then edit it. The easiest way to do this is using the service dashboard, which is described later._

# %% [markdown]
# ### Test your configuration
#
# It is a good idea to test your configuration on a small sample text before you apply it to a larger document collection.
#
# _**Note**: We have supplied a sample document (`data/sample.html`) containing the opening crawl text for Star Wars: Episode IV, but you are free to use a text of your choosing._
#
# **Q**: (optional) If you use your own sample text, provide a brief title and description below.
#
# **A**: Used default sample.

# %%
# Test configuration on some sample text
data_dir = "data"
filename = os.path.join(data_dir, "sample.html")
with open(filename, "r") as f:
    res = discovery.test_document(environment_id=env_id, configuration_id=cfg_id, fileinfo=f)
print(json.dumps(res, indent=2))
# Out:
# {
#   "enriched_field_units": 1,
#   "snapshots": [
#     {
#       "snapshot": {
#         "html": "<html>\n<head>\n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n</head>\n<body>\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body>"
#       },
#       "step": "html_input"
#     },
#     {
#       "snapshot": {
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n</head>\n<body>\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>"
#       },
#       "step": "html_output"
#     },
#     {
#       "snapshot": {
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "metadata": {},
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#       },
#       "step": "json_output"
#     },
#     {
#       "snapshot": {
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "metadata": {},
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#       },
#       "step": "json_normalizations_output"
#     },
#     {
#       "snapshot": {
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "metadata": {},
#         "enriched_text": {
#           "relations": [
#             {
#               "action": {
#                 "text": "is",
#                 "verb": {
#                   "tense": "present",
#                   "text": "be"
#                 },
#                 "lemmatized": "be"
#               },
#               "object": {
#                 "sentiment": {
#                   "type": "negative",
#                   "score": -0.564509,
#                   "mixed": false
#                 },
#                 "text": "a period of civil war",
#                 "entities": [
#                   {
#                     "type": "FieldTerminology",
#                     "text": "civil war"
#                   }
#                 ],
#                 "keywords": [
#                   {
#                     "text": "civil war"
#                   },
#                   {
#                     "text": "period"
#                   }
#                 ]
#               },
#               "sentence": " It is a period of civil war.",
#               "subject": {
#                 "text": "It"
#               }
#             },
#             {
#               "action": {
#                 "text": "have won",
#                 "verb": {
#                   "tense": "past",
#                   "text": "win"
#                 },
#                 "lemmatized": "have win"
#               },
#               "object": {
#                 "text": "their first victory",
#                 "keywords": [
#                   {
#                     "text": "victory"
#                   }
#                 ]
#               },
#               "sentence": " Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.",
#               "subject": {
#                 "text": "Rebel spaceships, striking from a hidden base,",
#                 "keywords": [
#                   {
#                     "text": "Rebel spaceships"
#                   },
#                   {
#                     "text": "hidden base"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "managed",
#                 "verb": {
#                   "tense": "past",
#                   "text": "manage"
#                 },
#                 "lemmatized": "manage"
#               },
#               "object": {
#                 "sentiment": {
#                   "type": "negative",
#                   "score": -0.596586,
#                   "mixed": false
#                 },
#                 "text": "to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet",
#                 "keywords": [
#                   {
#                     "text": "armored space station"
#                   },
#                   {
#                     "text": "ultimate weapon"
#                   },
#                   {
#                     "text": "secret plans"
#                   },
#                   {
#                     "text": "entire planet"
#                   }
#                 ]
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#               "subject": {
#                 "text": "Rebel spies",
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "managed to steal",
#                 "verb": {
#                   "tense": "future",
#                   "text": "steal"
#                 },
#                 "lemmatized": "manage to steal"
#               },
#               "object": {
#                 "text": "secret plans",
#                 "keywords": [
#                   {
#                     "text": "secret plans"
#                   }
#                 ]
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#               "subject": {
#                 "text": "Rebel spies",
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "to destroy",
#                 "verb": {
#                   "tense": "future",
#                   "text": "destroy"
#                 },
#                 "lemmatized": "to destroy"
#               },
#               "object": {
#                 "sentiment": {
#                   "type": "positive",
#                   "score": 0.748639,
#                   "mixed": false
#                 },
#                 "text": "an entire planet",
#                 "keywords": [
#                   {
#                     "text": "entire planet"
#                   }
#                 ],
#                 "sentimentFromSubject": {
#                   "type": "negative",
#                   "score": -0.754579,
#                   "mixed": false
#                 }
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#               "subject": {
#                 "text": "Rebel spies",
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "Pursued",
#                 "verb": {
#                   "tense": "past",
#                   "text": "Pursued"
#                 },
#                 "lemmatized": "Pursued"
#               },
#               "object": {
#                 "sentiment": {
#                   "type": "positive",
#                   "score": 0.682563,
#                   "mixed": false
#                 },
#                 "text": "Princess Leia",
#                 "keywords": [
#                   {
#                     "text": "Princess Leia"
#                   }
#                 ]
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "subject": {
#                 "sentiment": {
#                   "type": "positive",
#                   "score": 0.554106,
#                   "mixed": false
#                 },
#                 "text": "by the Empire",
#                 "keywords": [
#                   {
#                     "text": "Empire"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "can save",
#                 "verb": {
#                   "tense": "future",
#                   "text": "save"
#                 },
#                 "lemmatized": "can save"
#               },
#               "object": {
#                 "text": "her people",
#                 "keywords": [
#                   {
#                     "text": "people"
#                   }
#                 ]
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "subject": {
#                 "sentiment": {
#                   "type": "negative",
#                   "score": -0.44097,
#                   "mixed": false
#                 },
#                 "text": "the stolen plans",
#                 "keywords": [
#                   {
#                     "text": "plans"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "restore",
#                 "verb": {
#                   "tense": "future",
#                   "text": "restore"
#                 },
#                 "lemmatized": "restore"
#               },
#               "object": {
#                 "text": "to the galaxy",
#                 "keywords": [
#                   {
#                     "text": "galaxy"
#                   }
#                 ],
#                 "sentimentFromSubject": {
#                   "type": "positive",
#                   "score": 0.698799,
#                   "mixed": false
#                 }
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "subject": {
#                 "text": "freedom",
#                 "keywords": [
#                   {
#                     "text": "freedom"
#                   }
#                 ]
#               }
#             }
#           ],
#           "entities": [
#             {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.409172,
#                 "mixed": false
#               },
#               "type": "FieldTerminology",
#               "text": "civil war",
#               "count": 1,
#               "relevance": 0.972336
#             }
#           ],
#           "taxonomy": [
#             {
#               "label": "/art and entertainment/movies and tv/movies",
#               "score": 0.584247,
#               "confident": false
#             },
#             {
#               "label": "/society/unrest and war",
#               "score": 0.517031,
#               "confident": false
#             },
#             {
#               "label": "/law, govt and politics/armed forces/army",
#               "score": 0.215561,
#               "confident": false
#             }
#           ],
#           "concepts": [
#             {
#               "text": "Star Wars Episode IV: A New Hope",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwVH1ipwpEbGdrcN5Y29ycA",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope",
#               "relevance": 0.98887,
#               "freebase": "http://rdf.freebase.com/ns/m.0dtfn",
#               "website": "http://www.starwars.com/movies/episode-iv"
#             },
#             {
#               "text": "Star Wars",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars",
#               "relevance": 0.985705,
#               "yago": "http://yago-knowledge.org/resource/Star_Wars",
#               "freebase": "http://rdf.freebase.com/ns/m.06mmr",
#               "website": "http://www.starwars.com"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0nr1k",
#               "text": "Rebel Alliance",
#               "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#               "relevance": 0.90639,
#               "yago": "http://yago-knowledge.org/resource/Rebel_Alliance"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0f1bg",
#               "text": "Luke Skywalker",
#               "dbpedia": "http://dbpedia.org/resource/Luke_Skywalker",
#               "relevance": 0.805771,
#               "yago": "http://yago-knowledge.org/resource/Luke_Skywalker"
#             },
#             {
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back",
#               "text": "Star Wars Episode V: The Empire Strikes Back",
#               "website": "http://www.starwars.com/movies/episode-v",
#               "relevance": 0.801062,
#               "freebase": "http://rdf.freebase.com/ns/m.0f3m1"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0f2y0",
#               "text": "Darth Vader",
#               "dbpedia": "http://dbpedia.org/resource/Darth_Vader",
#               "relevance": 0.777337,
#               "yago": "http://yago-knowledge.org/resource/Darth_Vader"
#             },
#             {
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi",
#               "text": "Star Wars Episode VI: Return of the Jedi",
#               "website": "http://www.starwars.com/movies/episode-vi",
#               "relevance": 0.77159,
#               "freebase": "http://rdf.freebase.com/ns/m.0ddjy"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0jrsz",
#               "text": "Grand Moff Tarkin",
#               "dbpedia": "http://dbpedia.org/resource/Grand_Moff_Tarkin",
#               "relevance": 0.748553,
#               "yago": "http://yago-knowledge.org/resource/Grand_Moff_Tarkin"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0fdv3",
#               "text": "Star Wars Episode III: Revenge of the Sith",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith",
#               "relevance": 0.697065
#             },
#             {
#               "yago": "http://yago-knowledge.org/resource/Princess_Leia_Organa",
#               "text": "Princess Leia Organa",
#               "dbpedia": "http://dbpedia.org/resource/Princess_Leia_Organa",
#               "relevance": 0.607163
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0f325",
#               "text": "Death Star",
#               "dbpedia": "http://dbpedia.org/resource/Death_Star",
#               "relevance": 0.59271,
#               "yago": "http://yago-knowledge.org/resource/Death_Star"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0fjms",
#               "text": "Jabba the Hutt",
#               "dbpedia": "http://dbpedia.org/resource/Jabba_the_Hutt",
#               "relevance": 0.543114,
#               "yago": "http://yago-knowledge.org/resource/Jabba_the_Hutt"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0hwyg",
#               "text": "Galactic Empire",
#               "dbpedia": "http://dbpedia.org/resource/Galactic_Empire_(Star_Wars)",
#               "relevance": 0.523169,
#               "yago": "http://yago-knowledge.org/resource/Galactic_Empire_(Star_Wars)"
#             },
#             {
#               "yago": "http://yago-knowledge.org/resource/Star_Wars_galaxy",
#               "text": "Star Wars galaxy",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_galaxy",
#               "relevance": 0.519032
#             },
#             {
#               "text": "Star Wars Expanded Universe",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Expanded_Universe",
#               "relevance": 0.507885,
#               "yago": "http://yago-knowledge.org/resource/Star_Wars_Expanded_Universe",
#               "freebase": "http://rdf.freebase.com/ns/m.01qbrc",
#               "website": "http://www.starwars.com/eu"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.065lhy",
#               "text": "Alderaan",
#               "dbpedia": "http://dbpedia.org/resource/Alderaan",
#               "relevance": 0.503196,
#               "yago": "http://yago-knowledge.org/resource/Alderaan"
#             },
#             {
#               "text": "Carrie Fisher",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwSJnvZwpEbGdrcN5Y29ycA",
#               "freebase": "http://rdf.freebase.com/ns/m.01tnbn",
#               "relevance": 0.481464,
#               "yago": "http://yago-knowledge.org/resource/Carrie_Fisher",
#               "dbpedia": "http://dbpedia.org/resource/Carrie_Fisher"
#             },
#             {
#               "text": "Jedi",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwNLAD5wpEbGdrcN5Y29ycA",
#               "freebase": "http://rdf.freebase.com/ns/m.045n4",
#               "relevance": 0.474365,
#               "yago": "http://yago-knowledge.org/resource/Jedi",
#               "dbpedia": "http://dbpedia.org/resource/Jedi"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0199wf",
#               "text": "The Star Wars Holiday Special",
#               "dbpedia": "http://dbpedia.org/resource/The_Star_Wars_Holiday_Special",
#               "relevance": 0.4659,
#               "yago": "http://yago-knowledge.org/resource/The_Star_Wars_Holiday_Special"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0ddp_",
#               "text": "Wedge Antilles",
#               "dbpedia": "http://dbpedia.org/resource/Wedge_Antilles",
#               "relevance": 0.46456,
#               "yago": "http://yago-knowledge.org/resource/Wedge_Antilles"
#             },
#             {
#               "text": "English-language films",
#               "dbpedia": "http://dbpedia.org/resource/English-language_films",
#               "relevance": 0.460469
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0drf_",
#               "text": "Padm\u00e9 Amidala",
#               "dbpedia": "http://dbpedia.org/resource/Padm\u00e9_Amidala",
#               "relevance": 0.453766,
#               "yago": "http://yago-knowledge.org/resource/Padm%C3%A9_Amidala"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.01qc6_",
#               "text": "Galactic Civil War",
#               "dbpedia": "http://dbpedia.org/resource/Galactic_Civil_War",
#               "relevance": 0.447243,
#               "yago": "http://yago-knowledge.org/resource/Galactic_Civil_War"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0j_nw",
#               "text": "Spaceballs",
#               "dbpedia": "http://dbpedia.org/resource/Spaceballs",
#               "relevance": 0.436864,
#               "yago": "http://yago-knowledge.org/resource/Spaceballs"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.01qc6n",
#               "text": "Clone Wars",
#               "dbpedia": "http://dbpedia.org/resource/Clone_Wars_(Star_Wars)",
#               "relevance": 0.43403,
#               "yago": "http://yago-knowledge.org/resource/Clone_Wars_(Star_Wars)"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0g_sv",
#               "text": "C-3PO",
#               "dbpedia": "http://dbpedia.org/resource/C-3PO",
#               "relevance": 0.432345,
#               "yago": "http://yago-knowledge.org/resource/C-3PO"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0fkm7",
#               "text": "Obi-Wan Kenobi",
#               "dbpedia": "http://dbpedia.org/resource/Obi-Wan_Kenobi",
#               "relevance": 0.431988,
#               "yago": "http://yago-knowledge.org/resource/Obi-Wan_Kenobi"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0g_rg",
#               "text": "R2-D2",
#               "dbpedia": "http://dbpedia.org/resource/R2-D2",
#               "relevance": 0.430085,
#               "yago": "http://yago-knowledge.org/resource/R2-D2"
#             }
#           ],
#           "keywords": [
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Opening Crawl",
#               "relevance": 0.920159
#             },
#             {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.447888,
#                 "mixed": false
#               },
#               "text": "New Hope",
#               "relevance": 0.785031
#             },
#             {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.40059,
#                 "mixed": false
#               },
#               "text": "Princess Leia races",
#               "relevance": 0.775799
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Star Wars",
#               "relevance": 0.771384
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "evil Galactic Empire",
#               "relevance": 0.767527
#             },
#             {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.494714,
#                 "mixed": false
#               },
#               "text": "armored space station",
#               "relevance": 0.747615
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Rebel spaceships",
#               "relevance": 0.669776
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Rebel spies",
#               "relevance": 0.656828
#             },
#             {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.484685,
#                 "mixed": false
#               },
#               "text": "sinister agents",
#               "relevance": 0.609404
#             },
#             {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.409172,
#                 "mixed": false
#               },
#               "text": "civil war",
#               "relevance": 0.600682
#             },
#             {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.488854,
#                 "mixed": false
#               },
#               "text": "hidden base",
#               "relevance": 0.597836
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "ultimate weapon",
#               "relevance": 0.594694
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "secret plans",
#               "relevance": 0.582765
#             },
#             {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.494714,
#                 "mixed": false
#               },
#               "text": "entire planet",
#               "relevance": 0.582596
#             },
#             {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.430026,
#                 "mixed": false
#               },
#               "text": "DEATH STAR",
#               "relevance": 0.574413
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "custodian",
#               "relevance": 0.465394
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Episode",
#               "relevance": 0.462247
#             },
#             {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.40059,
#                 "mixed": false
#               },
#               "text": "starship",
#               "relevance": 0.443969
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "victory",
#               "relevance": 0.441799
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "galaxy",
#               "relevance": 0.437824
#             },
#             {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.409172,
#                 "mixed": false
#               },
#               "text": "period",
#               "relevance": 0.432092
#             },
#             {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.37594,
#                 "mixed": false
#               },
#               "text": "battle",
#               "relevance": 0.429238
#             },
#             {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.40059,
#                 "mixed": false
#               },
#               "text": "home",
#               "relevance": 0.428916
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "people",
#               "relevance": 0.428498
#             }
#           ],
#           "status": "OK",
#           "docSentiment": {
#             "type": "negative",
#             "score": -0.575489,
#             "mixed": false
#           },
#           "language": "english"
#         },
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#       },
#       "step": "enrichments_output"
#     },
#     {
#       "snapshot": {
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "metadata": {},
#         "enriched_text": {
#           "relations": [
#             {
#               "action": {
#                 "text": "is",
#                 "verb": {
#                   "tense": "present",
#                   "text": "be"
#                 },
#                 "lemmatized": "be"
#               },
#               "object": {
#                 "sentiment": {
#                   "type": "negative",
#                   "score": -0.564509,
#                   "mixed": false
#                 },
#                 "text": "a period of civil war",
#                 "entities": [
#                   {
#                     "type": "FieldTerminology",
#                     "text": "civil war"
#                   }
#                 ],
#                 "keywords": [
#                   {
#                     "text": "civil war"
#                   },
#                   {
#                     "text": "period"
#                   }
#                 ]
#               },
#               "sentence": " It is a period of civil war.",
#               "subject": {
#                 "text": "It"
#               }
#             },
#             {
#               "action": {
#                 "text": "have won",
#                 "verb": {
#                   "tense": "past",
#                   "text": "win"
#                 },
#                 "lemmatized": "have win"
#               },
#               "object": {
#                 "text": "their first victory",
#                 "keywords": [
#                   {
#                     "text": "victory"
#                   }
#                 ]
#               },
#               "sentence": " Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.",
#               "subject": {
#                 "text": "Rebel spaceships, striking from a hidden base,",
#                 "keywords": [
#                   {
#                     "text": "Rebel spaceships"
#                   },
#                   {
#                     "text": "hidden base"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "managed",
#                 "verb": {
#                   "tense": "past",
#                   "text": "manage"
#                 },
#                 "lemmatized": "manage"
#               },
#               "object": {
#                 "sentiment": {
#                   "type": "negative",
#                   "score": -0.596586,
#                   "mixed": false
#                 },
#                 "text": "to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet",
#                 "keywords": [
#                   {
#                     "text": "armored space station"
#                   },
#                   {
#                     "text": "ultimate weapon"
#                   },
#                   {
#                     "text": "secret plans"
#                   },
#                   {
#                     "text": "entire planet"
#                   }
#                 ]
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#               "subject": {
#                 "text": "Rebel spies",
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "managed to steal",
#                 "verb": {
#                   "tense": "future",
#                   "text": "steal"
#                 },
#                 "lemmatized": "manage to steal"
#               },
#               "object": {
#                 "text": "secret plans",
#                 "keywords": [
#                   {
#                     "text": "secret plans"
#                   }
#                 ]
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#               "subject": {
#                 "text": "Rebel spies",
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "to destroy",
#                 "verb": {
#                   "tense": "future",
#                   "text": "destroy"
#                 },
#                 "lemmatized": "to destroy"
#               },
#               "object": {
#                 "sentiment": {
#                   "type": "positive",
#                   "score": 0.748639,
#                   "mixed": false
#                 },
#                 "text": "an entire planet",
#                 "keywords": [
#                   {
#                     "text": "entire planet"
#                   }
#                 ],
#                 "sentimentFromSubject": {
#                   "type": "negative",
#                   "score": -0.754579,
#                   "mixed": false
#                 }
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#               "subject": {
#                 "text": "Rebel spies",
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "Pursued",
#                 "verb": {
#                   "tense": "past",
#                   "text": "Pursued"
#                 },
#                 "lemmatized": "Pursued"
#               },
#               "object": {
#                 "sentiment": {
#                   "type": "positive",
#                   "score": 0.682563,
#                   "mixed": false
#                 },
#                 "text": "Princess Leia",
#                 "keywords": [
#                   {
#                     "text": "Princess Leia"
#                   }
#                 ]
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "subject": {
#                 "sentiment": {
#                   "type": "positive",
#                   "score": 0.554106,
#                   "mixed": false
#                 },
#                 "text": "by the Empire",
#                 "keywords": [
#                   {
#                     "text": "Empire"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "can save",
#                 "verb": {
#                   "tense": "future",
#                   "text": "save"
#                 },
#                 "lemmatized": "can save"
#               },
#               "object": {
#                 "text": "her people",
#                 "keywords": [
#                   {
#                     "text": "people"
#                   }
#                 ]
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "subject": {
#                 "sentiment": {
#                   "type": "negative",
#                   "score": -0.44097,
#                   "mixed": false
#                 },
#                 "text": "the stolen plans",
#                 "keywords": [
#                   {
#                     "text": "plans"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "restore",
#                 "verb": {
#                   "tense": "future",
#                   "text": "restore"
#                 },
#                 "lemmatized": "restore"
#               },
#               "object": {
#                 "text": "to the galaxy",
#                 "keywords": [
#                   {
#                     "text": "galaxy"
#                   }
#                 ],
#                 "sentimentFromSubject": {
#                   "type": "positive",
#                   "score": 0.698799,
#                   "mixed": false
#                 }
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "subject": {
#                 "text": "freedom",
#                 "keywords": [
#                   {
#                     "text": "freedom"
#                   }
#                 ]
#               }
#             }
#           ],
#           "entities": [
#             {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.409172,
#                 "mixed": false
#               },
#               "type": "FieldTerminology",
#               "text": "civil war",
#               "count": 1,
#               "relevance": 0.972336
#             }
#           ],
#           "taxonomy": [
#             {
#               "label": "/art and entertainment/movies and tv/movies",
#               "score": 0.584247,
#               "confident": false
#             },
#             {
#               "label": "/society/unrest and war",
#               "score": 0.517031,
#               "confident": false
#             },
#             {
#               "label": "/law, govt and politics/armed forces/army",
#               "score": 0.215561,
#               "confident": false
#             }
#           ],
#           "concepts": [
#             {
#               "text": "Star Wars Episode IV: A New Hope",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwVH1ipwpEbGdrcN5Y29ycA",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope",
#               "relevance": 0.98887,
#               "freebase": "http://rdf.freebase.com/ns/m.0dtfn",
#               "website": "http://www.starwars.com/movies/episode-iv"
#             },
#             {
#               "text": "Star Wars",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars",
#               "relevance": 0.985705,
#               "yago": "http://yago-knowledge.org/resource/Star_Wars",
#               "freebase": "http://rdf.freebase.com/ns/m.06mmr",
#               "website": "http://www.starwars.com"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0nr1k",
#               "text": "Rebel Alliance",
#               "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#               "relevance": 0.90639,
#               "yago": "http://yago-knowledge.org/resource/Rebel_Alliance"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0f1bg",
#               "text": "Luke Skywalker",
#               "dbpedia": "http://dbpedia.org/resource/Luke_Skywalker",
#               "relevance": 0.805771,
#               "yago": "http://yago-knowledge.org/resource/Luke_Skywalker"
#             },
#             {
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back",
#               "text": "Star Wars Episode V: The Empire Strikes Back",
#               "website": "http://www.starwars.com/movies/episode-v",
#               "relevance": 0.801062,
#               "freebase": "http://rdf.freebase.com/ns/m.0f3m1"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0f2y0",
#               "text": "Darth Vader",
#               "dbpedia": "http://dbpedia.org/resource/Darth_Vader",
#               "relevance": 0.777337,
#               "yago": "http://yago-knowledge.org/resource/Darth_Vader"
#             },
#             {
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi",
#               "text": "Star Wars Episode VI: Return of the Jedi",
#               "website": "http://www.starwars.com/movies/episode-vi",
#               "relevance": 0.77159,
#               "freebase": "http://rdf.freebase.com/ns/m.0ddjy"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0jrsz",
#               "text": "Grand Moff Tarkin",
#               "dbpedia": "http://dbpedia.org/resource/Grand_Moff_Tarkin",
#               "relevance": 0.748553,
#               "yago": "http://yago-knowledge.org/resource/Grand_Moff_Tarkin"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0fdv3",
#               "text": "Star Wars Episode III: Revenge of the Sith",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith",
#               "relevance": 0.697065
#             },
#             {
#               "yago": "http://yago-knowledge.org/resource/Princess_Leia_Organa",
#               "text": "Princess Leia Organa",
#               "dbpedia": "http://dbpedia.org/resource/Princess_Leia_Organa",
#               "relevance": 0.607163
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0f325",
#               "text": "Death Star",
#               "dbpedia": "http://dbpedia.org/resource/Death_Star",
#               "relevance": 0.59271,
#               "yago": "http://yago-knowledge.org/resource/Death_Star"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0fjms",
#               "text": "Jabba the Hutt",
#               "dbpedia": "http://dbpedia.org/resource/Jabba_the_Hutt",
#               "relevance": 0.543114,
#               "yago": "http://yago-knowledge.org/resource/Jabba_the_Hutt"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0hwyg",
#               "text": "Galactic Empire",
#               "dbpedia": "http://dbpedia.org/resource/Galactic_Empire_(Star_Wars)",
#               "relevance": 0.523169,
#               "yago": "http://yago-knowledge.org/resource/Galactic_Empire_(Star_Wars)"
#             },
#             {
#               "yago": "http://yago-knowledge.org/resource/Star_Wars_galaxy",
#               "text": "Star Wars galaxy",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_galaxy",
#               "relevance": 0.519032
#             },
#             {
#               "text": "Star Wars Expanded Universe",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Expanded_Universe",
#               "relevance": 0.507885,
#               "yago": "http://yago-knowledge.org/resource/Star_Wars_Expanded_Universe",
#               "freebase": "http://rdf.freebase.com/ns/m.01qbrc",
#               "website": "http://www.starwars.com/eu"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.065lhy",
#               "text": "Alderaan",
#               "dbpedia": "http://dbpedia.org/resource/Alderaan",
#               "relevance": 0.503196,
#               "yago": "http://yago-knowledge.org/resource/Alderaan"
#             },
#             {
#               "text": "Carrie Fisher",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwSJnvZwpEbGdrcN5Y29ycA",
#               "freebase": "http://rdf.freebase.com/ns/m.01tnbn",
#               "relevance": 0.481464,
#               "yago": "http://yago-knowledge.org/resource/Carrie_Fisher",
#               "dbpedia": "http://dbpedia.org/resource/Carrie_Fisher"
#             },
#             {
#               "text": "Jedi",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwNLAD5wpEbGdrcN5Y29ycA",
#               "freebase": "http://rdf.freebase.com/ns/m.045n4",
#               "relevance": 0.474365,
#               "yago": "http://yago-knowledge.org/resource/Jedi",
#               "dbpedia": "http://dbpedia.org/resource/Jedi"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0199wf",
#               "text": "The Star Wars Holiday Special",
#               "dbpedia": "http://dbpedia.org/resource/The_Star_Wars_Holiday_Special",
#               "relevance": 0.4659,
#               "yago": "http://yago-knowledge.org/resource/The_Star_Wars_Holiday_Special"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0ddp_",
#               "text": "Wedge Antilles",
#               "dbpedia": "http://dbpedia.org/resource/Wedge_Antilles",
#               "relevance": 0.46456,
#               "yago": "http://yago-knowledge.org/resource/Wedge_Antilles"
#             },
#             {
#               "text": "English-language films",
#               "dbpedia": "http://dbpedia.org/resource/English-language_films",
#               "relevance": 0.460469
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0drf_",
#               "text": "Padm\u00e9 Amidala",
#               "dbpedia": "http://dbpedia.org/resource/Padm\u00e9_Amidala",
#               "relevance": 0.453766,
#               "yago": "http://yago-knowledge.org/resource/Padm%C3%A9_Amidala"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.01qc6_",
#               "text": "Galactic Civil War",
#               "dbpedia": "http://dbpedia.org/resource/Galactic_Civil_War",
#               "relevance": 0.447243,
#               "yago": "http://yago-knowledge.org/resource/Galactic_Civil_War"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0j_nw",
#               "text": "Spaceballs",
#               "dbpedia": "http://dbpedia.org/resource/Spaceballs",
#               "relevance": 0.436864,
#               "yago": "http://yago-knowledge.org/resource/Spaceballs"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.01qc6n",
#               "text": "Clone Wars",
#               "dbpedia": "http://dbpedia.org/resource/Clone_Wars_(Star_Wars)",
#               "relevance": 0.43403,
#               "yago": "http://yago-knowledge.org/resource/Clone_Wars_(Star_Wars)"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0g_sv",
#               "text": "C-3PO",
#               "dbpedia": "http://dbpedia.org/resource/C-3PO",
#               "relevance": 0.432345,
#               "yago": "http://yago-knowledge.org/resource/C-3PO"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0fkm7",
#               "text": "Obi-Wan Kenobi",
#               "dbpedia": "http://dbpedia.org/resource/Obi-Wan_Kenobi",
#               "relevance": 0.431988,
#               "yago": "http://yago-knowledge.org/resource/Obi-Wan_Kenobi"
#             },
#             {
#               "freebase": "http://rdf.freebase.com/ns/m.0g_rg",
#               "text": "R2-D2",
#               "dbpedia": "http://dbpedia.org/resource/R2-D2",
#               "relevance": 0.430085,
#               "yago": "http://yago-knowledge.org/resource/R2-D2"
#             }
#           ],
#           "keywords": [
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Opening Crawl",
#               "relevance": 0.920159
#             },
#             {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.447888,
#                 "mixed": false
#               },
#               "text": "New Hope",
#               "relevance": 0.785031
#             },
#             {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.40059,
#                 "mixed": false
#               },
#               "text": "Princess Leia races",
#               "relevance": 0.775799
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Star Wars",
#               "relevance": 0.771384
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "evil Galactic Empire",
#               "relevance": 0.767527
#             },
#             {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.494714,
#                 "mixed": false
#               },
#               "text": "armored space station",
#               "relevance": 0.747615
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Rebel spaceships",
#               "relevance": 0.669776
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Rebel spies",
#               "relevance": 0.656828
#             },
#             {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.484685,
#                 "mixed": false
#               },
#               "text": "sinister agents",
#               "relevance": 0.609404
#             },
#             {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.409172,
#                 "mixed": false
#               },
#               "text": "civil war",
#               "relevance": 0.600682
#             },
#             {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.488854,
#                 "mixed": false
#               },
#               "text": "hidden base",
#               "relevance": 0.597836
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "ultimate weapon",
#               "relevance": 0.594694
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "secret plans",
#               "relevance": 0.582765
#             },
#             {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.494714,
#                 "mixed": false
#               },
#               "text": "entire planet",
#               "relevance": 0.582596
#             },
#             {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.430026,
#                 "mixed": false
#               },
#               "text": "DEATH STAR",
#               "relevance": 0.574413
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "custodian",
#               "relevance": 0.465394
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Episode",
#               "relevance": 0.462247
#             },
#             {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.40059,
#                 "mixed": false
#               },
#               "text": "starship",
#               "relevance": 0.443969
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "victory",
#               "relevance": 0.441799
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "galaxy",
#               "relevance": 0.437824
#             },
#             {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.409172,
#                 "mixed": false
#               },
#               "text": "period",
#               "relevance": 0.432092
#             },
#             {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.37594,
#                 "mixed": false
#               },
#               "text": "battle",
#               "relevance": 0.429238
#             },
#             {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.40059,
#                 "mixed": false
#               },
#               "text": "home",
#               "relevance": 0.428916
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "people",
#               "relevance": 0.428498
#             }
#           ],
#           "status": "OK",
#           "docSentiment": {
#             "type": "negative",
#             "score": -0.575489,
#             "mixed": false
#           },
#           "language": "english"
#         },
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#       },
#       "step": "normalizations_output"
#     }
#   ],
#   "notices": [],
#   "original_media_type": "text/html",
#   "status": "completed"
# }

# %% [markdown]
# ### Analyze test output
#
# The results returned by the service contain a _snapshot_ of the information extracted at each step of processing - document conversions, enrichments and normalizations. We are interested in the output of applying enrichments (`"enrichments_output"`) or after normalizing them (`"normalizations_output"`). These should be identical if no post-processing/normalizations were specified in the configuration.

# %%
# Take a closer look at the results from the "enrichments_output" or "normalizations_output" step
output = next((s["snapshot"] for s in res["snapshots"] if s["step"] == "enrichments_output"), None)
print(json.dumps(output, indent=2))
# Out:
# {
#   "extracted_metadata": {
#     "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#   },
#   "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#   "metadata": {},
#   "enriched_text": {
#     "relations": [
#       {
#         "action": {
#           "text": "is",
#           "verb": {
#             "tense": "present",
#             "text": "be"
#           },
#           "lemmatized": "be"
#         },
#         "object": {
#           "sentiment": {
#             "type": "negative",
#             "score": -0.564509,
#             "mixed": false
#           },
#           "text": "a period of civil war",
#           "entities": [
#             {
#               "type": "FieldTerminology",
#               "text": "civil war"
#             }
#           ],
#           "keywords": [
#             {
#               "text": "civil war"
#             },
#             {
#               "text": "period"
#             }
#           ]
#         },
#         "sentence": " It is a period of civil war.",
#         "subject": {
#           "text": "It"
#         }
#       },
#       {
#         "action": {
#           "text": "have won",
#           "verb": {
#             "tense": "past",
#             "text": "win"
#           },
#           "lemmatized": "have win"
#         },
#         "object": {
#           "text": "their first victory",
#           "keywords": [
#             {
#               "text": "victory"
#             }
#           ]
#         },
#         "sentence": " Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.",
#         "subject": {
#           "text": "Rebel spaceships, striking from a hidden base,",
#           "keywords": [
#             {
#               "text": "Rebel spaceships"
#             },
#             {
#               "text": "hidden base"
#             }
#           ]
#         }
#       },
#       {
#         "action": {
#           "text": "managed",
#           "verb": {
#             "tense": "past",
#             "text": "manage"
#           },
#           "lemmatized": "manage"
#         },
#         "object": {
#           "sentiment": {
#             "type": "negative",
#             "score": -0.596586,
#             "mixed": false
#           },
#           "text": "to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet",
#           "keywords": [
#             {
#               "text": "armored space station"
#             },
#             {
#               "text": "ultimate weapon"
#             },
#             {
#               "text": "secret plans"
#             },
#             {
#               "text": "entire planet"
#             }
#           ]
#         },
#         "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#         "subject": {
#           "text": "Rebel spies",
#           "keywords": [
#             {
#               "text": "Rebel spies"
#             }
#           ]
#         }
#       },
#       {
#         "action": {
#           "text": "managed to steal",
#           "verb": {
#             "tense": "future",
#             "text": "steal"
#           },
#           "lemmatized": "manage to steal"
#         },
#         "object": {
#           "text": "secret plans",
#           "keywords": [
#             {
#               "text": "secret plans"
#             }
#           ]
#         },
#         "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#         "subject": {
#           "text": "Rebel spies",
#           "keywords": [
#             {
#               "text": "Rebel spies"
#             }
#           ]
#         }
#       },
#       {
#         "action": {
#           "text": "to destroy",
#           "verb": {
#             "tense": "future",
#             "text": "destroy"
#           },
#           "lemmatized": "to destroy"
#         },
#         "object": {
#           "sentiment": {
#             "type": "positive",
#             "score": 0.748639,
#             "mixed": false
#           },
#           "text": "an entire planet",
#           "keywords": [
#             {
#               "text": "entire planet"
#             }
#           ],
#           "sentimentFromSubject": {
#             "type": "negative",
#             "score": -0.754579,
#             "mixed": false
#           }
#         },
#         "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#         "subject": {
#           "text": "Rebel spies",
#           "keywords": [
#             {
#               "text": "Rebel spies"
#             }
#           ]
#         }
#       },
#       {
#         "action": {
#           "text": "Pursued",
#           "verb": {
#             "tense": "past",
#             "text": "Pursued"
#           },
#           "lemmatized": "Pursued"
#         },
#         "object": {
#           "sentiment": {
#             "type": "positive",
#             "score": 0.682563,
#             "mixed": false
#           },
#           "text": "Princess Leia",
#           "keywords": [
#             {
#               "text": "Princess Leia"
#             }
#           ]
#         },
#         "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "subject": {
#           "sentiment": {
#             "type": "positive",
#             "score": 0.554106,
#             "mixed": false
#           },
#           "text": "by the Empire",
#           "keywords": [
#             {
#               "text": "Empire"
#             }
#           ]
#         }
#       },
#       {
#         "action": {
#           "text": "can save",
#           "verb": {
#             "tense": "future",
#             "text": "save"
#           },
#           "lemmatized": "can save"
#         },
#         "object": {
#           "text": "her people",
#           "keywords": [
#             {
#               "text": "people"
#             }
#           ]
#         },
#         "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "subject": {
#           "sentiment": {
#             "type": "negative",
#             "score": -0.44097,
#             "mixed": false
#           },
#           "text": "the stolen plans",
#           "keywords": [
#             {
#               "text": "plans"
#             }
#           ]
#         }
#       },
#       {
#         "action": {
#           "text": "restore",
#           "verb": {
#             "tense": "future",
#             "text": "restore"
#           },
#           "lemmatized": "restore"
#         },
#         "object": {
#           "text": "to the galaxy",
#           "keywords": [
#             {
#               "text": "galaxy"
#             }
#           ],
#           "sentimentFromSubject": {
#             "type": "positive",
#             "score": 0.698799,
#             "mixed": false
#           }
#         },
#         "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "subject": {
#           "text": "freedom",
#           "keywords": [
#             {
#               "text": "freedom"
#             }
#           ]
#         }
#       }
#     ],
#     "entities": [
#       {
#         "sentiment": {
#           "type": "negative",
#           "score": -0.409172,
#           "mixed": false
#         },
#         "type": "FieldTerminology",
#         "text": "civil war",
#         "count": 1,
#         "relevance": 0.972336
#       }
#     ],
#     "taxonomy": [
#       {
#         "label": "/art and entertainment/movies and tv/movies",
#         "score": 0.584247,
#         "confident": false
#       },
#       {
#         "label": "/society/unrest and war",
#         "score": 0.517031,
#         "confident": false
#       },
#       {
#         "label": "/law, govt and politics/armed forces/army",
#         "score": 0.215561,
#         "confident": false
#       }
#     ],
#     "concepts": [
#       {
#         "text": "Star Wars Episode IV: A New Hope",
#         "opencyc": "http://sw.opencyc.org/concept/Mx4rwVH1ipwpEbGdrcN5Y29ycA",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope",
#         "relevance": 0.98887,
#         "freebase": "http://rdf.freebase.com/ns/m.0dtfn",
#         "website": "http://www.starwars.com/movies/episode-iv"
#       },
#       {
#         "text": "Star Wars",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars",
#         "relevance": 0.985705,
#         "yago": "http://yago-knowledge.org/resource/Star_Wars",
#         "freebase": "http://rdf.freebase.com/ns/m.06mmr",
#         "website": "http://www.starwars.com"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.0nr1k",
#         "text": "Rebel Alliance",
#         "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#         "relevance": 0.90639,
#         "yago": "http://yago-knowledge.org/resource/Rebel_Alliance"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.0f1bg",
#         "text": "Luke Skywalker",
#         "dbpedia": "http://dbpedia.org/resource/Luke_Skywalker",
#         "relevance": 0.805771,
#         "yago": "http://yago-knowledge.org/resource/Luke_Skywalker"
#       },
#       {
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back",
#         "text": "Star Wars Episode V: The Empire Strikes Back",
#         "website": "http://www.starwars.com/movies/episode-v",
#         "relevance": 0.801062,
#         "freebase": "http://rdf.freebase.com/ns/m.0f3m1"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.0f2y0",
#         "text": "Darth Vader",
#         "dbpedia": "http://dbpedia.org/resource/Darth_Vader",
#         "relevance": 0.777337,
#         "yago": "http://yago-knowledge.org/resource/Darth_Vader"
#       },
#       {
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi",
#         "text": "Star Wars Episode VI: Return of the Jedi",
#         "website": "http://www.starwars.com/movies/episode-vi",
#         "relevance": 0.77159,
#         "freebase": "http://rdf.freebase.com/ns/m.0ddjy"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.0jrsz",
#         "text": "Grand Moff Tarkin",
#         "dbpedia": "http://dbpedia.org/resource/Grand_Moff_Tarkin",
#         "relevance": 0.748553,
#         "yago": "http://yago-knowledge.org/resource/Grand_Moff_Tarkin"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.0fdv3",
#         "text": "Star Wars Episode III: Revenge of the Sith",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith",
#         "relevance": 0.697065
#       },
#       {
#         "yago": "http://yago-knowledge.org/resource/Princess_Leia_Organa",
#         "text": "Princess Leia Organa",
#         "dbpedia": "http://dbpedia.org/resource/Princess_Leia_Organa",
#         "relevance": 0.607163
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.0f325",
#         "text": "Death Star",
#         "dbpedia": "http://dbpedia.org/resource/Death_Star",
#         "relevance": 0.59271,
#         "yago": "http://yago-knowledge.org/resource/Death_Star"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.0fjms",
#         "text": "Jabba the Hutt",
#         "dbpedia": "http://dbpedia.org/resource/Jabba_the_Hutt",
#         "relevance": 0.543114,
#         "yago": "http://yago-knowledge.org/resource/Jabba_the_Hutt"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.0hwyg",
#         "text": "Galactic Empire",
#         "dbpedia": "http://dbpedia.org/resource/Galactic_Empire_(Star_Wars)",
#         "relevance": 0.523169,
#         "yago": "http://yago-knowledge.org/resource/Galactic_Empire_(Star_Wars)"
#       },
#       {
#         "yago": "http://yago-knowledge.org/resource/Star_Wars_galaxy",
#         "text": "Star Wars galaxy",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_galaxy",
#         "relevance": 0.519032
#       },
#       {
#         "text": "Star Wars Expanded Universe",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Expanded_Universe",
#         "relevance": 0.507885,
#         "yago": "http://yago-knowledge.org/resource/Star_Wars_Expanded_Universe",
#         "freebase": "http://rdf.freebase.com/ns/m.01qbrc",
#         "website": "http://www.starwars.com/eu"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.065lhy",
#         "text": "Alderaan",
#         "dbpedia": "http://dbpedia.org/resource/Alderaan",
#         "relevance": 0.503196,
#         "yago": "http://yago-knowledge.org/resource/Alderaan"
#       },
#       {
#         "text": "Carrie Fisher",
#         "opencyc": "http://sw.opencyc.org/concept/Mx4rwSJnvZwpEbGdrcN5Y29ycA",
#         "freebase": "http://rdf.freebase.com/ns/m.01tnbn",
#         "relevance": 0.481464,
#         "yago": "http://yago-knowledge.org/resource/Carrie_Fisher",
#         "dbpedia": "http://dbpedia.org/resource/Carrie_Fisher"
#       },
#       {
#         "text": "Jedi",
#         "opencyc": "http://sw.opencyc.org/concept/Mx4rwNLAD5wpEbGdrcN5Y29ycA",
#         "freebase": "http://rdf.freebase.com/ns/m.045n4",
#         "relevance": 0.474365,
#         "yago": "http://yago-knowledge.org/resource/Jedi",
#         "dbpedia": "http://dbpedia.org/resource/Jedi"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.0199wf",
#         "text": "The Star Wars Holiday Special",
#         "dbpedia": "http://dbpedia.org/resource/The_Star_Wars_Holiday_Special",
#         "relevance": 0.4659,
#         "yago": "http://yago-knowledge.org/resource/The_Star_Wars_Holiday_Special"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.0ddp_",
#         "text": "Wedge Antilles",
#         "dbpedia": "http://dbpedia.org/resource/Wedge_Antilles",
#         "relevance": 0.46456,
#         "yago": "http://yago-knowledge.org/resource/Wedge_Antilles"
#       },
#       {
#         "text": "English-language films",
#         "dbpedia": "http://dbpedia.org/resource/English-language_films",
#         "relevance": 0.460469
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.0drf_",
#         "text": "Padm\u00e9 Amidala",
#         "dbpedia": "http://dbpedia.org/resource/Padm\u00e9_Amidala",
#         "relevance": 0.453766,
#         "yago": "http://yago-knowledge.org/resource/Padm%C3%A9_Amidala"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.01qc6_",
#         "text": "Galactic Civil War",
#         "dbpedia": "http://dbpedia.org/resource/Galactic_Civil_War",
#         "relevance": 0.447243,
#         "yago": "http://yago-knowledge.org/resource/Galactic_Civil_War"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.0j_nw",
#         "text": "Spaceballs",
#         "dbpedia": "http://dbpedia.org/resource/Spaceballs",
#         "relevance": 0.436864,
#         "yago": "http://yago-knowledge.org/resource/Spaceballs"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.01qc6n",
#         "text": "Clone Wars",
#         "dbpedia": "http://dbpedia.org/resource/Clone_Wars_(Star_Wars)",
#         "relevance": 0.43403,
#         "yago": "http://yago-knowledge.org/resource/Clone_Wars_(Star_Wars)"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.0g_sv",
#         "text": "C-3PO",
#         "dbpedia": "http://dbpedia.org/resource/C-3PO",
#         "relevance": 0.432345,
#         "yago": "http://yago-knowledge.org/resource/C-3PO"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.0fkm7",
#         "text": "Obi-Wan Kenobi",
#         "dbpedia": "http://dbpedia.org/resource/Obi-Wan_Kenobi",
#         "relevance": 0.431988,
#         "yago": "http://yago-knowledge.org/resource/Obi-Wan_Kenobi"
#       },
#       {
#         "freebase": "http://rdf.freebase.com/ns/m.0g_rg",
#         "text": "R2-D2",
#         "dbpedia": "http://dbpedia.org/resource/R2-D2",
#         "relevance": 0.430085,
#         "yago": "http://yago-knowledge.org/resource/R2-D2"
#       }
#     ],
#     "keywords": [
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "Opening Crawl",
#         "relevance": 0.920159
#       },
#       {
#         "sentiment": {
#           "type": "positive",
#           "score": 0.447888,
#           "mixed": false
#         },
#         "text": "New Hope",
#         "relevance": 0.785031
#       },
#       {
#         "sentiment": {
#           "type": "positive",
#           "score": 0.40059,
#           "mixed": false
#         },
#         "text": "Princess Leia races",
#         "relevance": 0.775799
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "Star Wars",
#         "relevance": 0.771384
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "evil Galactic Empire",
#         "relevance": 0.767527
#       },
#       {
#         "sentiment": {
#           "type": "negative",
#           "score": -0.494714,
#           "mixed": false
#         },
#         "text": "armored space station",
#         "relevance": 0.747615
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "Rebel spaceships",
#         "relevance": 0.669776
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "Rebel spies",
#         "relevance": 0.656828
#       },
#       {
#         "sentiment": {
#           "type": "positive",
#           "score": 0.484685,
#           "mixed": false
#         },
#         "text": "sinister agents",
#         "relevance": 0.609404
#       },
#       {
#         "sentiment": {
#           "type": "negative",
#           "score": -0.409172,
#           "mixed": false
#         },
#         "text": "civil war",
#         "relevance": 0.600682
#       },
#       {
#         "sentiment": {
#           "type": "positive",
#           "score": 0.488854,
#           "mixed": false
#         },
#         "text": "hidden base",
#         "relevance": 0.597836
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "ultimate weapon",
#         "relevance": 0.594694
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "secret plans",
#         "relevance": 0.582765
#       },
#       {
#         "sentiment": {
#           "type": "negative",
#           "score": -0.494714,
#           "mixed": false
#         },
#         "text": "entire planet",
#         "relevance": 0.582596
#       },
#       {
#         "sentiment": {
#           "type": "negative",
#           "score": -0.430026,
#           "mixed": false
#         },
#         "text": "DEATH STAR",
#         "relevance": 0.574413
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "custodian",
#         "relevance": 0.465394
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "Episode",
#         "relevance": 0.462247
#       },
#       {
#         "sentiment": {
#           "type": "positive",
#           "score": 0.40059,
#           "mixed": false
#         },
#         "text": "starship",
#         "relevance": 0.443969
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "victory",
#         "relevance": 0.441799
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "galaxy",
#         "relevance": 0.437824
#       },
#       {
#         "sentiment": {
#           "type": "negative",
#           "score": -0.409172,
#           "mixed": false
#         },
#         "text": "period",
#         "relevance": 0.432092
#       },
#       {
#         "sentiment": {
#           "type": "negative",
#           "score": -0.37594,
#           "mixed": false
#         },
#         "text": "battle",
#         "relevance": 0.429238
#       },
#       {
#         "sentiment": {
#           "type": "positive",
#           "score": 0.40059,
#           "mixed": false
#         },
#         "text": "home",
#         "relevance": 0.428916
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "people",
#         "relevance": 0.428498
#       }
#     ],
#     "status": "OK",
#     "docSentiment": {
#       "type": "negative",
#       "score": -0.575489,
#       "mixed": false
#     },
#     "language": "english"
#   },
#   "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
# }

# %% [markdown]
# Answer the following questions based on the output above. Note that it contains the input HTML, extracted text and metadata as well as the actual enrichment results (`"enriched_text"` block).
#
# #### Sentiment
#
# **Q**: What is the overall sentiment detected in this text? Mention the `type` (positive/negative) and `score`.<br />
# (_Hint: Look for the `"docSentiment"` key in the output._)
#
# **A**: Overall sentiment is Negative with a score of -0.575489.
#
#
# #### Concepts
#
# **Q**: List 3 concepts that have been identified with a relevance > 0.5. Note that not all concepts here may be present directly in the text, some may have been inferred by Watson.<br />
# (_Hint: Look for `"concepts"`._)
#
# **A**: "Star Wars" - relevance: 0.985705  ----- "Rebel Alliance" - relevance: 0.90639 ----- "Darth Vader" - relevance: 0.777337
#
#
# #### Relations
#
# Each relation is essentially a deeper analysis of a sentence (or part of a sentence). Here is a sample relation:
# ```json
# {
#   "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#   "subject": {
#     "text": "Rebel spies",
#     "keywords": [
#       {
#         "text": "Rebel spies"
#       }
#     ]
#   },
#   "action": {
#     "text": "managed to steal",
#     "lemmatized": "manage to steal",
#     "verb": {
#       "text": "steal",
#       "tense": "future"
#     }
#   },
#   "object": {
#     "text": "secret plans",
#     "keywords": [
#       {
#         "text": "secret plans"
#       }
#     ]
#   }
#  }
# ```
#
# In this case, Watson seems to have done a pretty good job of extracting some meaning from the sentence.
#
# **Q**: Find a relation where the extracted meaning is not as accurate, or not what you would've expected. List the `sentence`, `subject`, `action` and `object` parts as identified, and what you would've marked instead.<br />
# (_Hint: Look for `"relations"`._)
#
# **A**:
# {
#         "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#         "subject": {
#           "keywords": [
#             {
#               "text": "Rebel spies"
#             }
#           ],
#           "text": "Rebel spies"
#         },
#         "action": {
#           "verb": {
#             "text": "destroy",
#             "tense": "future"
#           },
#           "text": "to destroy",
#           "lemmatized": "to destroy"
#         },
#         "object": {
#           "sentimentFromSubject": {
#             "score": -0.754579,
#             "mixed": false,
#             "type": "negative"
#           },
#           "sentiment": {
#             "score": 0.748639,
#             "mixed": false,
#             "type": "positive"
#           },
#           "text": "an entire planet",
#           "keywords": [
#             {
#               "text": "entire planet"
#             }
#           ]
#         }
#       },
#
#       In this example, action of destroying an entire planet has been related to Rebel spies in a sense that they want to destroy the planet. However, ability of destroying the planet is actually refering to Death Star, so the correct keyword in above relation would have been DEATH STAR and not Rebel spies.
#
# #### Keywords
#
# You may have noticed that Watson identifies some `"keywords"` in the relations, e.g. `"Rebel spies"` and `"secret plans"` in the Star Wars example above. The output also contains a list of all keywords at the top level, for your convenience, along with their relevance to the document and sentiment conveyed. Let's visualize these keywords as a word cloud!
#
# Note: We'll be using this handy [worldcoud library](https://github.com/amueller/word_cloud) to generate the visualization. So you will need to install it first:
# ```bash
# pip install wordcloud
# ```

# %%
# Visualize keywords by relevance as a wordcloud
from wordcloud import WordCloud

wc_data = { w["text"]: w["relevance"] for w in output["enriched_text"]["keywords"] }
wc = WordCloud(width=400, height=300, scale=2, background_color="black", colormap="Vega10")
wc.generate_from_frequencies(wc_data)  # use precomputed relevance instead of frequencies

plt.figure(figsize=(4, 3), dpi=200)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# c:\users\rojin\.conda\envs\aind-tf\lib\site-packages\matplotlib\cbook.py:136: MatplotlibDeprecationWarning: The Vega10 colormap was deprecated in version 2.0. Use tab10 instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# (-0.5, 799.5, 599.5, -0.5)

# %% [markdown]
# Feel free to play with this visualization and improve it. What about using a different metric instead of relevance, e.g. direct word frequencies that the wordcloud library computes by default?
#
# #### Other results
#
# Watson's output also includes processed results from other enrichments that were applied to the text, including entities and taxonomy (what topic or category does this text relate to).
#
# ```json
# "taxonomy": [
#   {
#     "label": "/art and entertainment/movies and tv/movies",
#     "score": 0.584247,
#     "confident": false
#   },
#   {
#     "label": "/society/unrest and war",
#     "score": 0.517031,
#     "confident": false
#   },
#   {
#     "confident": false,
#     "label": "/law, govt and politics/armed forces/army",
#     "score": 0.215561
#   }
# ],
# ```
#
# Get a good sense of all the different pieces of information available in the results. Start thinking about which ones will be useful for looking up answers to questions, and how you might use them.

# %% [markdown]
# ## 2. Ingest documents
#
# ### Create a collection
#
# A _collection_ is used to organize documents of the same kind. For instance, you may want to create a collection of book reviews, or a collection of Wikipedia articles, but it may not make much sense to mix the two groups. This allows Watson to make meaningful inferences over the set of documents, find commonalities and identify important concepts.
#
# Let's create one called "Story Chunks".

# %%
# Prepare a collection of documents to use
col, col_id = helper.fetch_object(discovery, "collection", "Story Chunks", environment_id=env_id,
    create=True, create_args=dict(
        environment_id=env_id, configuration_id=cfg_id,
        description="Stories and plots split up into chunks suitable for answering"
    ))
print(json.dumps(col, indent=2))
# Out:
# Found collection: Story Chunks (190cbb71-da76-4dfd-ac4e-465a3101d394)
# {
#   "created": "2017-06-18T21:29:53.950Z",
#   "training_status": {
#     "notices": 0,
#     "sufficient_label_diversity": false,
#     "successfully_trained": "",
#     "total_examples": 0,
#     "processing": false,
#     "minimum_examples_added": false,
#     "data_updated": "",
#     "available": false,
#     "minimum_queries_added": false
#   },
#   "configuration_id": "7d6901e3-0d6f-422e-bba8-a428af92f901",
#   "document_counts": {
#     "available": 294,
#     "failed": 0,
#     "processing": 0
#   },
#   "collection_id": "190cbb71-da76-4dfd-ac4e-465a3101d394",
#   "updated": "2017-06-18T21:29:53.950Z",
#   "description": "Stories and plots split up into chunks suitable for answering",
#   "language": "en",
#   "name": "Story Chunks",
#   "status": "active"
# }

# %% [markdown]
# Once you have created a collection, you should be able to view it using the Discovery Service tool. To open, go to the **Manage** tab for your service instance, and click the **Launch tool** button.
#
# <img src="images/discovery-manage.png" alt="Discovery service - Manage tab" width="800" />

# %% [markdown]
# Here you should see the "Story Chunks" collection you just created.
#
# <img src="images/discovery-tooling.png" alt="Discovery service - Tool showing collections" width="800" />
#
# You can open the collection to view more details about it. If you need to modify configuration options, click the **Switch** link and create a new configuration (the default one cannot be changed).

# %% [markdown]
# ### Add documents
#
# Okay, now that we have everything set up, let's add a set of "documents" we want Watson to look up answers from, using the Python SDK. Note that Watson treats each "document" as a unit of text that is returned as the result of a query. But we want to retrieve a paragraph of text for each question. So, let's split each file up into individual paragraphs. We will use the [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) library for this purpose.
#
# _**Note**: You could also add and manage documents in the collection using the Discovery tool, but you would have to split paragraphs up into separate files._
#
# _**Note**: We have provided a set of files (`data/Star-Wars/*.html`) with summary plots for Star Wars movies, but you are free to use a collection of your choice. Open one of the files in a text editor to see how the paragraphs are delimited using `<p>...</p>` tags - this is how the code block below split paragraphs into separate "documents"._

# %%
# Add documents to collection
doc_ids = []  # to store the generated id for each document added
for filename in glob.glob(os.path.join(data_dir, "Star-Wars", "*.html")):
    print("Adding file:", filename)
    with open(filename, "r") as f:
        # Split each individual <p> into its own "document"
        doc = f.read()
        soup = BeautifulSoup(doc, 'html.parser')
        for i, p in enumerate(soup.find_all('p')):
            doc_info = discovery.add_document(environment_id=env_id, collection_id=col_id,
                file_data=json.dumps({"text": p.get_text(strip=True)}),
                mime_type="application/json",
                metadata={"title": soup.title.get_text(strip=True)})
            doc_ids.append(doc_info["document_id"])
print("Total", len(doc_ids), "documents added.")
# Out:
# Adding file: data\Star-Wars\Episode-III_Revenge-of-the-Sith.html
# Adding file: data\Star-Wars\Episode-II_Attack-of-the-Clones.html
# Adding file: data\Star-Wars\Episode-IV_A-New-Hope.html
# Adding file: data\Star-Wars\Episode-I_The-Phantom-Menace.html
# Adding file: data\Star-Wars\Episode-VII_The-Force-Awakens.html
# Adding file: data\Star-Wars\Episode-VI_Return-of-the-Jedi.html
# Adding file: data\Star-Wars\Episode-V_The-Empire-Strikes-Back.html
# Adding file: data\Star-Wars\Rogue-One.html
# Total 42 documents added.

# %% [markdown]
# If you look at the collection details, you may notice that the `"document_counts"` field now shows some documents as `available` or `processing`. Once processing is complete, you should see all the documents under the `available` count.

# %%
# View collection details to verify all documents have been processed
col, col_id = helper.fetch_object(discovery, "collection", "Story Chunks", environment_id=env_id)
print(json.dumps(col, indent=2))
# Out:
# Found collection: Story Chunks (190cbb71-da76-4dfd-ac4e-465a3101d394)
# {
#   "created": "2017-06-18T21:29:53.950Z",
#   "training_status": {
#     "notices": 0,
#     "sufficient_label_diversity": false,
#     "successfully_trained": "",
#     "total_examples": 0,
#     "processing": false,
#     "minimum_examples_added": false,
#     "data_updated": "",
#     "available": false,
#     "minimum_queries_added": false
#   },
#   "configuration_id": "7d6901e3-0d6f-422e-bba8-a428af92f901",
#   "document_counts": {
#     "available": 336,
#     "failed": 0,
#     "processing": 0
#   },
#   "collection_id": "190cbb71-da76-4dfd-ac4e-465a3101d394",
#   "updated": "2017-06-18T21:29:53.950Z",
#   "description": "Stories and plots split up into chunks suitable for answering",
#   "language": "en",
#   "name": "Story Chunks",
#   "status": "active"
# }

# %% [markdown]
# So, what did the Discovery service learn? If you list the fields extracted from the set of documents in the collection as part of the enrichment process, you'll see familiar fields like `concepts`, `entities` and `keywords` that were returned in the test analysis.

# %%
# List all fields extracted
discovery.list_collection_fields(environment_id=env_id, collection_id=col_id)
# Out:
# {'fields': [{'field': '190cbb71-da76-4dfd-ac4e-465a3101d394.mappings.document._all.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text', 'type': 'nested'},
#   {'field': 'extracted_metadata', 'type': 'nested'},
#   {'field': 'metadata', 'type': 'nested'},
#   {'field': 'text', 'type': 'string'},
#   {'field': 'text.analyzer', 'type': 'english'},
#   {'field': 'enriched_text.properties.concepts', 'type': 'nested'},
#   {'field': 'enriched_text.properties.docSentiment', 'type': 'nested'},
#   {'field': 'enriched_text.properties.entities', 'type': 'nested'},
#   {'field': 'enriched_text.properties.keywords', 'type': 'nested'},
#   {'field': 'enriched_text.properties.language', 'type': 'string'},
#   {'field': 'enriched_text.properties.language.analyzer', 'type': 'english'},
#   {'field': 'enriched_text.properties.relations', 'type': 'nested'},
#   {'field': 'enriched_text.properties.status', 'type': 'string'},
#   {'field': 'enriched_text.properties.status.analyzer', 'type': 'english'},
#   {'field': 'enriched_text.properties.taxonomy', 'type': 'nested'},
#   {'field': 'extracted_metadata.properties.file_type', 'type': 'string'},
#   {'field': 'extracted_metadata.properties.file_type.analyzer',
#    'type': 'english'},
#   {'field': 'extracted_metadata.properties.filename', 'type': 'string'},
#   {'field': 'extracted_metadata.properties.filename.analyzer',
#    'type': 'english'},
#   {'field': 'extracted_metadata.properties.sha1', 'type': 'string'},
#   {'field': 'extracted_metadata.properties.sha1.analyzer', 'type': 'english'},
#   {'field': 'metadata.properties.title', 'type': 'string'},
#   {'field': 'metadata.properties.title.analyzer', 'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.ciaFactbook',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.ciaFactbook.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.dbpedia.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.freebase.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.geo',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.geo.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.musicBrainz',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.musicBrainz.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.opencyc',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.opencyc.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.relevance',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.concepts.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.website',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.website.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.yago',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.yago.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.docSentiment.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.docSentiment.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.docSentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.docSentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.count',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.entities.properties.quotations',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.entities.properties.relevance',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.entities.properties.sentiment',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.entities.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.keywords.properties.relevance',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.keywords.properties.sentiment',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.keywords.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.keywords.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.location',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.sentence',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.sentence.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.taxonomy.properties.confident',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.taxonomy.properties.label',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.taxonomy.properties.label.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.taxonomy.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.dbpedia.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.freebase.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.name',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.name.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.yago',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.yago.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.quotations.properties.quotation',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.quotations.properties.quotation.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.quotations.properties.sentiment',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.entities.properties.sentiment.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.entities.properties.sentiment.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.entities.properties.sentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.sentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.keywords.properties.sentiment.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.keywords.properties.sentiment.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.keywords.properties.sentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.keywords.properties.sentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.lemmatized',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.lemmatized.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.verb',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.sentiment',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.keywords',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentiment',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.keywords',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.sentiment',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.quotations.properties.sentiment.properties.score',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.quotations.properties.sentiment.properties.score.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.quotations.properties.sentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.quotations.properties.sentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.verb.properties.tense',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.verb.properties.tense.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.verb.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.verb.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.sentiment.properties.score',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.sentiment.properties.score.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.sentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.sentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.keywords.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.keywords.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentiment.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentiment.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.keywords.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.keywords.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.sentiment.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.sentiment.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.sentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.sentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.dbpedia.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.freebase.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.name',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.name.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.yago',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.yago.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.dbpedia.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.freebase.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.name',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.name.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.yago',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.yago.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.dbpedia.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.freebase.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.name',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.name.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.yago',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.yago.analyzer',
#    'type': 'english'}]}

# %% [markdown]
# ### Test query
#
# Let's perform a simple query to see if the service can fetch the proper document for us:
# > _Look for all paragraphs that have a relation (sentence) with "Jar Jar" as the subject, and return the title and text._

# %%
# A simple query
results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        #"query": "enriched_text.entities.type::Facility",
        "aggregation": "nested(enriched_text.entities).filter(enriched_text.entities.type::Facility).term(enriched_text.entities.text)"
        #"return": "metadata.title, enriched_text.relations"
    })


print(json.dumps(results, indent=2))
# Out:
# {
#   "results": [
#     {
#       "text": "On Geonosis, Obi-Wan discovers a Separatist gathering led by Count Dooku, whom Obi-Wan learns had authorized Padm\u00c3\u00a9's assassination and is developing a battle droid army with Trade Federation Viceroy Nute Gunray. Obi-Wan transmits his findings to Anakin to relay to the Jedi Council, but is captured mid-transmission. With knowledge of the droid army, Supreme Chancellor Palpatine is voted emergency powers to send the clones into battle. Anakin and Padm\u00c3\u00a9 journey to Geonosis to rescue Obi-Wan, but are also captured. The three are sentenced to death, but are eventually saved by a battalion of Jedi and clone troopers led by Mace Windu and Yoda; Jango Fett is killed by Mace during the rescue. As the clone and droid armies battle, Obi-Wan and Anakin intercept Dooku, and the three engage in a lightsaber battle. Dooku overpowers Obi-Wan and Anakin, severing the latter's arm, but Yoda arrives and duels the count. Finding he is unable to defeat Yoda, Dooku flees to Coruscant, where he delivers blueprints for a superweapon to his Sith master, Darth Sidious. As the Jedi gravely acknowledge the beginning of the Clone Wars, Anakin is fitted with a robotic arm and secretly marries Padm\u00c3\u00a9 on Naboo, with C-3PO and R2-D2 as their witnesses.",
#       "score": 1.0,
#       "enriched_text": {
#         "relations": [
#           {
#             "action": {
#               "text": "discovers",
#               "verb": {
#                 "tense": "present",
#                 "text": "discover"
#               },
#               "lemmatized": "discover"
#             },
#             "object": {
#               "text": "a Separatist gathering led by Count Dooku",
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Count Dooku"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Separatist gathering"
#                 },
#                 {
#                   "text": "Count Dooku"
#                 }
#               ]
#             },
#             "sentence": "On Geonosis, Obi-Wan discovers a Separatist gathering led by Count Dooku, whom Obi-Wan learns had authorized Padm\u00c3\u00a9's assassination and is developing a battle droid army with Trade Federation Viceroy Nute Gunray.",
#             "subject": {
#               "text": "Obi-Wan",
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Obi-Wan"
#                 }
#               ]
#             }
#           },
#           {
#             "action": {
#               "text": "led",
#               "verb": {
#                 "tense": "past",
#                 "text": "lead"
#               },
#               "lemmatized": "lead"
#             },
#             "object": {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.517673,
#                 "mixed": false
#               },
#               "text": "a Separatist gathering",
#               "keywords": [
#                 {
#                   "text": "Separatist gathering"
#                 }
#               ]
#             },
#             "sentence": "On Geonosis, Obi-Wan discovers a Separatist gathering led by Count Dooku, whom Obi-Wan learns had authorized Padm\u00c3\u00a9's assassination and is developing a battle droid army with Trade Federation Viceroy Nute Gunray.",
#             "subject": {
#               "text": "by Count Dooku",
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Count Dooku"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Count Dooku"
#                 }
#               ]
#             }
#           },
#           {
#             "action": {
#               "text": "had authorized",
#               "verb": {
#                 "tense": "past",
#                 "text": "authorize"
#               },
#               "lemmatized": "have authorize"
#             },
#             "object": {
#               "text": "Padm\u00c3\u00a9's assassination",
#               "keywords": [
#                 {
#                   "text": "assassination"
#                 },
#                 {
#                   "text": "Padm\u00c3\u00a9"
#                 }
#               ],
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Padm\u00c3\u00a9"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "type": "positive",
#                 "score": 0.667144,
#                 "mixed": false
#               }
#             },
#             "sentence": "On Geonosis, Obi-Wan discovers a Separatist gathering led by Count Dooku, whom Obi-Wan learns had authorized Padm\u00c3\u00a9's assassination and is developing a battle droid army with Trade Federation Viceroy Nute Gunray.",
#             "subject": {
#               "text": "Dooku",
#               "keywords": [
#                 {
#                   "text": "Dooku"
#                 }
#               ]
#             }
#           },
#           {
#             "action": {
#               "text": "is",
#               "verb": {
#                 "tense": "present",
#                 "text": "be"
#               },
#               "lemmatized": "be"
#             },
#             "object": {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.453689,
#                 "mixed": false
#               },
#               "text": "with Trade Federation Viceroy Nute Gunray",
#               "entities": [
#                 {
#                   "type": "Organization",
#                   "text": "Trade Federation"
#                 },
#                 {
#                   "type": "Person",
#                   "text": "Viceroy Nute Gunray"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Federation Viceroy Nute"
#                 }
#               ]
#             },
#             "sentence": "On Geonosis, Obi-Wan discovers a Separatist gathering led by Count Dooku, whom Obi-Wan learns had authorized Padm\u00c3\u00a9's assassination and is developing a battle droid army with Trade Federation Viceroy Nute Gunray.",
#             "subject": {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.524461,
#                 "mixed": false
#               },
#               "text": "developing a battle droid army",
#               "entities": [
#                 {
#                   "type": "Organization",
#                   "text": "droid army"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "battle droid army"
#                 }
#               ]
#             }
#           },
#           {
#             "action": {
#               "text": "is",
#               "verb": {
#                 "tense": "present",
#                 "text": "be"
#               },
#               "lemmatized": "be"
#             },
#             "object": {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.42147,
#                 "mixed": false
#               },
#               "text": "voted emergency powers to send the clones into battle",
#               "keywords": [
#                 {
#                   "text": "emergency powers"
#                 },
#                 {
#                   "text": "clones"
#                 },
#                 {
#                   "text": "battle"
#                 }
#               ]
#             },
#             "sentence": " With knowledge of the droid army, Supreme Chancellor Palpatine is voted emergency powers to send the clones into battle.",
#             "subject": {
#               "text": "Supreme Chancellor Palpatine",
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Supreme Chancellor Palpatine"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Supreme Chancellor"
#                 }
#               ]
#             }
#           },
#           {
#             "action": {
#               "text": "is voted",
#               "verb": {
#                 "tense": "past",
#                 "text": "vote"
#               },
#               "lemmatized": "be vote"
#             },
#             "object": {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.452598,
#                 "mixed": false
#               },
#               "text": "emergency powers to send the clones into battle",
#               "keywords": [
#                 {
#                   "text": "emergency powers"
#                 },
#                 {
#                   "text": "clones"
#                 },
#                 {
#                   "text": "battle"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "type": "positive",
#                 "score": 0.640435,
#                 "mixed": false
#               }
#             },
#             "sentence": " With knowledge of the droid army, Supreme Chancellor Palpatine is voted emergency powers to send the clones into battle.",
#             "subject": {
#               "text": "Supreme Chancellor Palpatine",
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Supreme Chancellor Palpatine"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Supreme Chancellor"
#                 }
#               ]
#             }
#           },
#           {
#             "action": {
#               "text": "to send",
#               "verb": {
#                 "tense": "future",
#                 "text": "send"
#               },
#               "lemmatized": "to send"
#             },
#             "object": {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.635249,
#                 "mixed": false
#               },
#               "text": "into battle",
#               "keywords": [
#                 {
#                   "text": "battle"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "type": "positive",
#                 "score": 0.523711,
#                 "mixed": false
#               }
#             },
#             "sentence": " With knowledge of the droid army, Supreme Chancellor Palpatine is voted emergency powers to send the clones into battle.",
#             "subject": {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.502286,
#                 "mixed": false
#               },
#               "text": "the clones",
#               "keywords": [
#                 {
#                   "text": "clones"
#                 }
#               ]
#             }
#           },
#           {
#             "action": {
#               "text": "are sentenced",
#               "verb": {
#                 "tense": "past",
#                 "text": "sentence"
#               },
#               "lemmatized": "be sentence"
#             },
#             "object": {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.588894,
#                 "mixed": false
#               },
#               "text": "to death",
#               "keywords": [
#                 {
#                   "text": "death"
#                 }
#               ]
#             },
#             "sentence": " The three are sentenced to death, but are eventually saved by a battalion of Jedi and clone troopers led by Mace Windu and Yoda; Jango Fett is killed by Mace during the rescue.",
#             "subject": {
#               "text": "The three"
#             }
#           },
#           {
#             "action": {
#               "text": "are",
#               "verb": {
#                 "tense": "present",
#                 "text": "be"
#               },
#               "lemmatized": "be"
#             },
#             "sentence": " The three are sentenced to death, but are eventually saved by a battalion of Jedi and clone troopers led by Mace Windu and Yoda; Jango Fett is killed by Mace during the rescue.",
#             "subject": {
#               "text": "The three"
#             }
#           },
#           {
#             "action": {
#               "text": "saved",
#               "verb": {
#                 "tense": "past",
#                 "text": "save"
#               },
#               "lemmatized": "save"
#             },
#             "object": {
#               "text": "The three",
#               "sentimentFromSubject": {
#                 "type": "positive",
#                 "score": 0.64654,
#                 "mixed": false
#               }
#             },
#             "sentence": " The three are sentenced to death, but are eventually saved by a battalion of Jedi and clone troopers led by Mace Windu and Yoda; Jango Fett is killed by Mace during the rescue.",
#             "subject": {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.521995,
#                 "mixed": false
#               },
#               "text": "by a battalion of Jedi and clone troopers led by Mace Windu and Yoda",
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Mace Windu"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Mace Windu"
#                 },
#                 {
#                   "text": "Yoda"
#                 },
#                 {
#                   "text": "troopers"
#                 },
#                 {
#                   "text": "battalion"
#                 }
#               ]
#             }
#           },
#           {
#             "action": {
#               "text": "led",
#               "verb": {
#                 "tense": "past",
#                 "text": "lead"
#               },
#               "lemmatized": "lead"
#             },
#             "object": {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.647737,
#                 "mixed": false
#               },
#               "text": "clone troopers",
#               "keywords": [
#                 {
#                   "text": "clone troopers"
#                 }
#               ]
#             },
#             "sentence": " The three are sentenced to death, but are eventually saved by a battalion of Jedi and clone troopers led by Mace Windu and Yoda; Jango Fett is killed by Mace during the rescue.",
#             "subject": {
#               "text": "by Mace Windu and Yoda",
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Mace Windu"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Mace Windu"
#                 },
#                 {
#                   "text": "Yoda"
#                 }
#               ]
#             }
#           },
#           {
#             "action": {
#               "text": "is killed",
#               "verb": {
#                 "tense": "present",
#                 "text": "be"
#               },
#               "lemmatized": "be kill"
#             },
#             "sentence": " The three are sentenced to death, but are eventually saved by a battalion of Jedi and clone troopers led by Mace Windu and Yoda; Jango Fett is killed by Mace during the rescue.",
#             "subject": {
#               "text": "Jango Fett",
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Jango Fett"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Jango Fett"
#                 }
#               ]
#             }
#           },
#           {
#             "action": {
#               "text": "is killed",
#               "verb": {
#                 "tense": "past",
#                 "text": "kill"
#               },
#               "lemmatized": "be kill"
#             },
#             "object": {
#               "text": "Jango Fett",
#               "keywords": [
#                 {
#                   "text": "Jango Fett"
#                 }
#               ],
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Jango Fett"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "type": "negative",
#                 "score": -0.765995,
#                 "mixed": false
#               }
#             },
#             "sentence": " The three are sentenced to death, but are eventually saved by a battalion of Jedi and clone troopers led by Mace Windu and Yoda; Jango Fett is killed by Mace during the rescue.",
#             "subject": {
#               "text": "by Mace",
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Mace Windu"
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Mace"
#                 }
#               ]
#             }
#           },
#           {
#             "action": {
#               "text": "to defeat",
#               "verb": {
#                 "tense": "future",
#                 "text": "defeat"
#               },
#               "lemmatized": "to defeat"
#             },
#             "object": {
#               "text": "Yoda",
#               "keywords": [
#                 {
#                   "text": "Yoda"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "type": "negative",
#                 "score": -0.498498,
#                 "mixed": false
#               }
#             },
#             "sentence": " Finding he is unable to defeat Yoda, Dooku flees to Coruscant, where he delivers blueprints for a superweapon to his Sith master, Darth Sidious.",
#             "subject": {
#               "text": "he"
#             }
#           },
#           {
#             "action": {
#               "text": "delivers",
#               "verb": {
#                 "tense": "present",
#                 "text": "deliver"
#               },
#               "lemmatized": "deliver"
#             },
#             "object": {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.451691,
#                 "mixed": false
#               },
#               "text": "blueprints",
#               "keywords": [
#                 {
#                   "text": "blueprints"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "type": "positive",
#                 "score": 0.689345,
#                 "mixed": false
#               }
#             },
#             "sentence": " Finding he is unable to defeat Yoda, Dooku flees to Coruscant, where he delivers blueprints for a superweapon to his Sith master, Darth Sidious.",
#             "subject": {
#               "text": "he",
#               "entities": [
#                 {
#                   "type": "Person",
#                   "text": "Count Dooku"
#                 }
#               ]
#             }
#           },
#           {
#             "action": {
#               "text": "acknowledge",
#               "verb": {
#                 "tense": "present",
#                 "text": "acknowledge"
#               },
#               "lemmatized": "acknowledge"
#             },
#             "object": {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.357087,
#                 "mixed": false
#               },
#               "text": "the beginning of the Clone Wars",
#               "keywords": [
#                 {
#                   "text": "Clone Wars"
#                 },
#                 {
#                   "text": "beginning"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "type": "positive",
#                 "score": 0.75056,
#                 "mixed": false
#               }
#             },
#             "sentence": " As the Jedi gravely acknowledge the beginning of the Clone Wars, Anakin is fitted with a robotic arm and secretly marries Padm\u00c3\u00a9 on Naboo, with C-3PO and R2-D2 as their witnesses.",
#             "subject": {
#               "text": "the Jedi",
#               "keywords": [
#                 {
#                   "text": "Jedi"
#                 }
#               ]
#             }
#           },
#           {
#             "action": {
#               "text": "is",
#               "verb": {
#                 "tense": "present",
#                 "text": "be"
#               },
#               "lemmatized": "be"
#             },
#             "object": {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.475643,
#                 "mixed": false
#               },
#               "text": "fitted with a robotic arm",
#               "keywords": [
#                 {
#                   "text": "robotic arm"
#                 }
#               ]
#             },
#             "sentence": " As the Jedi gravely acknowledge the beginning of the Clone Wars, Anakin is fitted with a robotic arm and secretly marries Padm\u00c3\u00a9 on Naboo, with C-3PO and R2-D2 as their witnesses.",
#             "subject": {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.754213,
#                 "mixed": false
#               },
#               "text": "Anakin",
#               "keywords": [
#                 {
#                   "text": "Anakin"
#                 }
#               ]
#             }
#           },
#           {
#             "action": {
#               "text": "is fitted",
#               "verb": {
#                 "tense": "past",
#                 "text": "fit"
#               },
#               "lemmatized": "be fit"
#             },
#             "object": {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.44567,
#                 "mixed": false
#               },
#               "text": "with a robotic arm",
#               "keywords": [
#                 {
#                   "text": "robotic arm"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "type": "positive",
#                 "score": 0.500845,
#                 "mixed": false
#               }
#             },
#             "sentence": " As the Jedi gravely acknowledge the beginning of the Clone Wars, Anakin is fitted with a robotic arm and secretly marries Padm\u00c3\u00a9 on Naboo, with C-3PO and R2-D2 as their witnesses.",
#             "subject": {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.754213,
#                 "mixed": false
#               },
#               "text": "Anakin",
#               "keywords": [
#                 {
#                   "text": "Anakin"
#                 }
#               ]
#             }
#           }
#         ],
#         "taxonomy": [
#           {
#             "label": "/law, govt and politics/armed forces/army",
#             "score": 0.614222,
#             "confident": false
#           },
#           {
#             "label": "/art and entertainment/movies and tv/movies",
#             "score": 0.479847,
#             "confident": false
#           },
#           {
#             "label": "/society/unrest and war",
#             "score": 0.151413,
#             "confident": false
#           }
#         ],
#         "concepts": [
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0dfw0",
#             "text": "Star Wars Episode II: Attack of the Clones",
#             "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_II:_Attack_of_the_Clones",
#             "relevance": 0.922782
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.03_5s0",
#             "text": "Palpatine",
#             "dbpedia": "http://dbpedia.org/resource/Palpatine",
#             "relevance": 0.800311,
#             "yago": "http://yago-knowledge.org/resource/Palpatine"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0fkm7",
#             "text": "Obi-Wan Kenobi",
#             "dbpedia": "http://dbpedia.org/resource/Obi-Wan_Kenobi",
#             "relevance": 0.751928,
#             "yago": "http://yago-knowledge.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0fdv3",
#             "text": "Star Wars Episode III: Revenge of the Sith",
#             "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith",
#             "relevance": 0.7517
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.01qc6n",
#             "text": "Clone Wars",
#             "dbpedia": "http://dbpedia.org/resource/Clone_Wars_(Star_Wars)",
#             "relevance": 0.662835,
#             "yago": "http://yago-knowledge.org/resource/Clone_Wars_(Star_Wars)"
#           },
#           {
#             "yago": "http://yago-knowledge.org/resource/Anakin_Skywalker",
#             "text": "Anakin Skywalker",
#             "dbpedia": "http://dbpedia.org/resource/Anakin_Skywalker",
#             "relevance": 0.619955
#           },
#           {
#             "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_I:_The_Phantom_Menace",
#             "text": "Star Wars Episode I: The Phantom Menace",
#             "website": "http://www.starwars.com/movies/episode-i/",
#             "relevance": 0.587378,
#             "freebase": "http://rdf.freebase.com/ns/m.0ddt_"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0g_rz",
#             "text": "Mace Windu",
#             "dbpedia": "http://dbpedia.org/resource/Mace_Windu",
#             "relevance": 0.587052,
#             "yago": "http://yago-knowledge.org/resource/Mace_Windu"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0g_tb",
#             "text": "Yoda",
#             "dbpedia": "http://dbpedia.org/resource/Yoda",
#             "relevance": 0.559267,
#             "yago": "http://yago-knowledge.org/resource/Yoda"
#           },
#           {
#             "text": "Star Wars",
#             "dbpedia": "http://dbpedia.org/resource/Star_Wars",
#             "relevance": 0.545269,
#             "yago": "http://yago-knowledge.org/resource/Star_Wars",
#             "freebase": "http://rdf.freebase.com/ns/m.06mmr",
#             "website": "http://www.starwars.com"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0gzf3",
#             "text": "Count Dooku",
#             "dbpedia": "http://dbpedia.org/resource/Count_Dooku",
#             "relevance": 0.525648,
#             "yago": "http://yago-knowledge.org/resource/Count_Dooku"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0drf_",
#             "text": "Padm\u00e9 Amidala",
#             "dbpedia": "http://dbpedia.org/resource/Padm\u00e9_Amidala",
#             "relevance": 0.517347,
#             "yago": "http://yago-knowledge.org/resource/Padm%C3%A9_Amidala"
#           },
#           {
#             "text": "Star Wars characters",
#             "dbpedia": "http://dbpedia.org/resource/Star_Wars_characters",
#             "relevance": 0.506437
#           },
#           {
#             "text": "Jedi",
#             "opencyc": "http://sw.opencyc.org/concept/Mx4rwNLAD5wpEbGdrcN5Y29ycA",
#             "freebase": "http://rdf.freebase.com/ns/m.045n4",
#             "relevance": 0.499403,
#             "yago": "http://yago-knowledge.org/resource/Jedi",
#             "dbpedia": "http://dbpedia.org/resource/Jedi"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0f2y0",
#             "text": "Darth Vader",
#             "dbpedia": "http://dbpedia.org/resource/Darth_Vader",
#             "relevance": 0.470247,
#             "yago": "http://yago-knowledge.org/resource/Darth_Vader"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.03clky",
#             "text": "Jedi Council",
#             "dbpedia": "http://dbpedia.org/resource/Jedi_Council",
#             "relevance": 0.430961,
#             "yago": "http://yago-knowledge.org/resource/Jedi_Council"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.03c9ct",
#             "text": "General Grievous",
#             "dbpedia": "http://dbpedia.org/resource/General_Grievous",
#             "relevance": 0.429689,
#             "yago": "http://yago-knowledge.org/resource/General_Grievous"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0hvfy",
#             "text": "Sith",
#             "dbpedia": "http://dbpedia.org/resource/Sith",
#             "relevance": 0.425358,
#             "yago": "http://yago-knowledge.org/resource/Sith"
#           },
#           {
#             "dbpedia": "http://dbpedia.org/resource/Star_Wars:_The_Clone_Wars_(film)",
#             "text": "Star Wars: The Clone Wars",
#             "website": "http://www.starwars.com/theclonewars",
#             "relevance": 0.395565,
#             "freebase": "http://rdf.freebase.com/ns/m.0cpllql"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.01k4x6",
#             "text": "Galactic Republic",
#             "dbpedia": "http://dbpedia.org/resource/Galactic_Republic",
#             "relevance": 0.391366,
#             "yago": "http://yago-knowledge.org/resource/Galactic_Republic"
#           },
#           {
#             "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi",
#             "text": "Star Wars Episode VI: Return of the Jedi",
#             "website": "http://www.starwars.com/movies/episode-vi",
#             "relevance": 0.390716,
#             "freebase": "http://rdf.freebase.com/ns/m.0ddjy"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0f1bg",
#             "text": "Luke Skywalker",
#             "dbpedia": "http://dbpedia.org/resource/Luke_Skywalker",
#             "relevance": 0.372881,
#             "yago": "http://yago-knowledge.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "opencyc": "http://sw.opencyc.org/concept/Mx4rwVH1ipwpEbGdrcN5Y29ycA",
#             "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope",
#             "relevance": 0.365108,
#             "freebase": "http://rdf.freebase.com/ns/m.0dtfn",
#             "website": "http://www.starwars.com/movies/episode-iv"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0hwyg",
#             "text": "Galactic Empire",
#             "dbpedia": "http://dbpedia.org/resource/Galactic_Empire_(Star_Wars)",
#             "relevance": 0.35148,
#             "yago": "http://yago-knowledge.org/resource/Galactic_Empire_(Star_Wars)"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0gzgj",
#             "text": "Qui-Gon Jinn",
#             "dbpedia": "http://dbpedia.org/resource/Qui-Gon_Jinn",
#             "relevance": 0.346682,
#             "yago": "http://yago-knowledge.org/resource/Qui-Gon_Jinn"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.01jyc9",
#             "text": "Coruscant",
#             "dbpedia": "http://dbpedia.org/resource/Coruscant",
#             "relevance": 0.342578,
#             "yago": "http://yago-knowledge.org/resource/Coruscant"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.01q927",
#             "text": "Trade Federation",
#             "dbpedia": "http://dbpedia.org/resource/Trade_Federation",
#             "relevance": 0.335253,
#             "yago": "http://yago-knowledge.org/resource/Trade_Federation"
#           },
#           {
#             "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back",
#             "text": "Star Wars Episode V: The Empire Strikes Back",
#             "website": "http://www.starwars.com/movies/episode-v",
#             "relevance": 0.329694,
#             "freebase": "http://rdf.freebase.com/ns/m.0f3m1"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.054ng5",
#             "text": "Asajj Ventress",
#             "dbpedia": "http://dbpedia.org/resource/Asajj_Ventress",
#             "relevance": 0.30897,
#             "yago": "http://yago-knowledge.org/resource/Asajj_Ventress"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0pk35",
#             "text": "Lightsaber",
#             "dbpedia": "http://dbpedia.org/resource/Lightsaber",
#             "relevance": 0.304434,
#             "yago": "http://yago-knowledge.org/resource/Lightsaber"
#           }
#         ],
#         "keywords": [
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.633169,
#               "mixed": false
#             },
#             "text": "Dooku overpowers Obi-Wan",
#             "relevance": 0.945654
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.592077,
#               "mixed": false
#             },
#             "text": "Anakin intercept Dooku",
#             "relevance": 0.925554
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "Obi-Wan learns",
#             "relevance": 0.775646
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "droid army",
#             "relevance": 0.770166
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "battle droid army",
#             "relevance": 0.767801
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.295896,
#               "mixed": false
#             },
#             "text": "Obi-Wan transmits",
#             "relevance": 0.751912
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "Federation Viceroy Nute",
#             "relevance": 0.737536
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "Count Dooku",
#             "relevance": 0.733685
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.363758,
#               "mixed": false
#             },
#             "text": "Mace Windu",
#             "relevance": 0.590602
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "Separatist gathering",
#             "relevance": 0.59046
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.295896,
#               "mixed": false
#             },
#             "text": "Jedi Council",
#             "relevance": 0.584541
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.37369,
#               "mixed": false
#             },
#             "text": "Jango Fett",
#             "relevance": 0.574673
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "Clone Wars",
#             "relevance": 0.565211
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "Darth Sidious",
#             "relevance": 0.555509
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.59056,
#               "mixed": false
#             },
#             "text": "lightsaber battle",
#             "relevance": 0.551714
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "emergency powers",
#             "relevance": 0.547772
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "robotic arm",
#             "relevance": 0.544568
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.531189,
#               "mixed": false
#             },
#             "text": "armies battle",
#             "relevance": 0.541979
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.361308,
#               "mixed": false
#             },
#             "text": "Padm\u00c3\u00a9 journey",
#             "relevance": 0.54091
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "Sith master",
#             "relevance": 0.539736
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.505503,
#               "mixed": false
#             },
#             "text": "Yoda",
#             "relevance": 0.512554
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.361308,
#               "mixed": false
#             },
#             "text": "Geonosis",
#             "relevance": 0.450002
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.358269,
#               "mixed": false
#             },
#             "text": "C-3PO",
#             "relevance": 0.444855
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.404228,
#               "mixed": false
#             },
#             "text": "Coruscant",
#             "relevance": 0.444122
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.358269,
#               "mixed": false
#             },
#             "text": "R2-D2",
#             "relevance": 0.438386
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "Naboo",
#             "relevance": 0.437933
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "clones",
#             "relevance": 0.432327
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "assassination",
#             "relevance": 0.432209
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.363758,
#               "mixed": false
#             },
#             "text": "troopers",
#             "relevance": 0.430689
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "blueprints",
#             "relevance": 0.428858
#           }
#         ],
#         "language": "english",
#         "entities": [
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.416427,
#               "mixed": false
#             },
#             "type": "Person",
#             "text": "Obi-Wan",
#             "count": 5,
#             "relevance": 0.914151
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.543158,
#               "mixed": false
#             },
#             "type": "Person",
#             "text": "Count Dooku",
#             "count": 5,
#             "relevance": 0.663562
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "type": "Person",
#             "text": "Anakin",
#             "count": 2,
#             "relevance": 0.458632
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "type": "Organization",
#             "text": "droid army",
#             "count": 2,
#             "relevance": 0.432113
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.295896,
#               "mixed": false
#             },
#             "disambiguated": {
#               "dbpedia": "http://dbpedia.org/resource/Jedi_Council",
#               "freebase": "http://rdf.freebase.com/ns/m.03clky",
#               "name": "Jedi Council",
#               "yago": "http://yago-knowledge.org/resource/Jedi_Council"
#             },
#             "relevance": 0.273961,
#             "type": "Organization",
#             "count": 1,
#             "text": "Jedi Council"
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.368724,
#               "mixed": false
#             },
#             "type": "Person",
#             "text": "Mace Windu",
#             "count": 2,
#             "relevance": 0.255948
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "type": "Person",
#             "text": "Viceroy Nute Gunray",
#             "count": 1,
#             "relevance": 0.250691
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "type": "Person",
#             "text": "Padm\u00c3\u00a9",
#             "count": 2,
#             "relevance": 0.247218
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.361308,
#               "mixed": false
#             },
#             "type": "Person",
#             "text": "Geonosis",
#             "count": 2,
#             "relevance": 0.239285
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "type": "Person",
#             "text": "Supreme Chancellor Palpatine",
#             "count": 1,
#             "relevance": 0.230348
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "type": "Person",
#             "text": "Darth Sidious",
#             "count": 1,
#             "relevance": 0.202256
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.37369,
#               "mixed": false
#             },
#             "type": "Person",
#             "text": "Jango Fett",
#             "count": 1,
#             "relevance": 0.181369
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "type": "Organization",
#             "text": "Trade Federation",
#             "count": 1,
#             "relevance": 0.163947
#           }
#         ],
#         "docSentiment": {
#           "type": "negative",
#           "score": -0.663691,
#           "mixed": false
#         },
#         "status": "OK"
#       },
#       "id": "68a643f3-b39e-44f2-b3ab-b69975bf7d44",
#       "extracted_metadata": {
#         "filename": "tmpfile",
#         "file_type": "json",
#         "sha1": "f8d009a557f78cb2fd4116d06856bbf8caff23be"
#       },
#       "metadata": {
#         "title": "Star Wars: Episode II - Attack of the Clones"
#       }
#     },
#     {
#       "text": "The galaxy is in the midst of a civil war. Spies for the Rebel Alliance have stolen plans to the Galactic Empire's Death Star, a heavily armed space station capable of destroying an entire planet. Rebel leader Princess Leia has the plans, but her ship is captured by Imperial forces under the command of the evil Darth Vader. Before she is captured, Leia hides the plans in the memory of an astromech droid, R2-D2, along with a holographic recording. R2-D2 flees to the surface of the desert planet Tatooine with C-3PO, a protocol droid.",
#       "score": 1.0,
#       "enriched_text": {
#         "relations": [
#           {
#             "action": {
#               "text": "is",
#               "verb": {
#                 "tense": "present",
#                 "text": "be"
#               },
#               "lemmatized": "be"
#             },
#             "sentence": "The galaxy is in the midst of a civil war.",
#             "subject": {
#               "text": "The galaxy",
#               "keywords": [
#                 {
#                   "text": "galaxy"
#                 }
#               ]
#             }
#           },
#           {
#             "action": {
#               "text": "have",
#               "verb": {
#                 "tense": "present",
#                 "text": "have"
#               },
#               "lemmatized": "have"
#             },
#             "object": {
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.594869,
#                 "mixed": false
#               },
#               "text": "stolen plans to the Galactic Empire's Death Star, a heavily armed space station capable of destroying an entire planet",
#               "keywords": [
#                 {
#                   "text": "heavily armed space"
#                 },
#                 {
#                   "text": "Galactic Empire"
#                 },
#                 {
#                   "text": "entire planet"
#                 },
#                 {
#                   "text": "Death Star"
#                 }
#               ]
#             },
#             "sentence": " Spies for the Rebel Alliance have stolen plans to the Galactic Empire's Death Star, a heavily armed space station capable of destroying an entire planet.",
#             "subject": {
#               "text": "Spies for the Rebel Alliance",
#               "entities": [
#                 {
#                   "type": "Organization",
#                   "text": "Rebel Alliance",
#                   "disambiguated": {
#                     "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#                     "freebase": "http://rdf.freebase.com/ns/m.0nr1k",
#                     "name": "Rebel Alliance",
#                     "yago": "http://yago-knowledge.org/resource/Rebel_Alliance"
#                   }
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Rebel Alliance"
#                 },
#                 {
#                   "text": "Spies"
#                 }
#               ]
#             }
#           },
#           {
#             "action": {
#               "text": "destroying",
#               "verb": {
#                 "tense": "future",
#                 "text": "destroy"
#               },
#               "lemmatized": "destroy"
#             },
#             "object": {
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.748639,
#                 "mixed": false
#               },
#               "text": "an entire planet",
#               "keywords": [
#                 {
#                   "text": "entire planet"
#                 }
#               ],
#               "sentimentFromSubject": {
#                 "type": "negative",
#                 "score": -0.395572,
#                 "mixed": false
#               }
#             },
#             "sentence": " Spies for the Rebel Alliance have stolen plans to the Galactic Empire's Death Star, a heavily armed space station capable of destroying an entire planet.",
#             "subject": {
#               "text": "Spies for the Rebel Alliance",
#               "entities": [
#                 {
#                   "type": "Organization",
#                   "text": "Rebel Alliance",
#                   "disambiguated": {
#                     "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#                     "freebase": "http://rdf.freebase.com/ns/m.0nr1k",
#                     "name": "Rebel Alliance",
#                     "yago": "http://yago-knowledge.org/resource/Rebel_Alliance"
#                   }
#                 }
#               ],
#               "keywords": [
#                 {
#                   "text": "Rebel Alliance"
#                 },
#                 {
#                   "text": "Spies"
#                 }
#               ]
#             }
#           },
#           {
#             "action": {
#               "text": "has",
#               "verb": {
#                 "tense": "present",
# ...
#           },
#           {
#             "label": "/art and entertainment/movies and tv/movies",
#             "score": 0.242985,
#             "confident": false
#           },
#           {
#             "label": "/law, govt and politics/armed forces/air force",
#             "score": 0.121916,
#             "confident": false
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "opencyc": "http://sw.opencyc.org/concept/Mx4rwVH1ipwpEbGdrcN5Y29ycA",
#             "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope",
#             "relevance": 0.965661,
#             "freebase": "http://rdf.freebase.com/ns/m.0dtfn",
#             "website": "http://www.starwars.com/movies/episode-iv"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0fdv3",
#             "text": "Star Wars Episode III: Revenge of the Sith",
#             "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith",
#             "relevance": 0.704354
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0f2y0",
#             "text": "Darth Vader",
#             "dbpedia": "http://dbpedia.org/resource/Darth_Vader",
#             "relevance": 0.680625,
#             "yago": "http://yago-knowledge.org/resource/Darth_Vader"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0fkm7",
#             "text": "Obi-Wan Kenobi",
#             "dbpedia": "http://dbpedia.org/resource/Obi-Wan_Kenobi",
#             "relevance": 0.645474,
#             "yago": "http://yago-knowledge.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0f1bg",
#             "text": "Luke Skywalker",
#             "dbpedia": "http://dbpedia.org/resource/Luke_Skywalker",
#             "relevance": 0.641051,
#             "yago": "http://yago-knowledge.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Star Wars",
#             "dbpedia": "http://dbpedia.org/resource/Star_Wars",
#             "relevance": 0.608656,
#             "yago": "http://yago-knowledge.org/resource/Star_Wars",
#             "freebase": "http://rdf.freebase.com/ns/m.06mmr",
#             "website": "http://www.starwars.com"
#           },
#           {
#             "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi",
#             "text": "Star Wars Episode VI: Return of the Jedi",
#             "website": "http://www.starwars.com/movies/episode-vi",
#             "relevance": 0.59977,
#             "freebase": "http://rdf.freebase.com/ns/m.0ddjy"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0g_rg",
#             "text": "R2-D2",
#             "dbpedia": "http://dbpedia.org/resource/R2-D2",
#             "relevance": 0.598672,
#             "yago": "http://yago-knowledge.org/resource/R2-D2"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0fkfk",
#             "text": "Chewbacca",
#             "dbpedia": "http://dbpedia.org/resource/Chewbacca",
#             "relevance": 0.594656,
#             "yago": "http://yago-knowledge.org/resource/Chewbacca"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0g_sv",
#             "text": "C-3PO",
#             "dbpedia": "http://dbpedia.org/resource/C-3PO",
#             "relevance": 0.573311,
#             "yago": "http://yago-knowledge.org/resource/C-3PO"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0fx5r",
#             "text": "Millennium Falcon",
#             "dbpedia": "http://dbpedia.org/resource/Millennium_Falcon",
#             "relevance": 0.555893,
#             "yago": "http://yago-knowledge.org/resource/Millennium_Falcon"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0fjn8",
#             "text": "Han Solo",
#             "dbpedia": "http://dbpedia.org/resource/Han_Solo",
#             "relevance": 0.530251,
#             "yago": "http://yago-knowledge.org/resource/Han_Solo"
#           },
#           {
#             "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back",
#             "text": "Star Wars Episode V: The Empire Strikes Back",
#             "website": "http://www.starwars.com/movies/episode-v",
#             "relevance": 0.515385,
#             "freebase": "http://rdf.freebase.com/ns/m.0f3m1"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0ddrb",
#             "text": "Lando Calrissian",
#             "dbpedia": "http://dbpedia.org/resource/Lando_Calrissian",
#             "relevance": 0.471236,
#             "yago": "http://yago-knowledge.org/resource/Lando_Calrissian"
#           },
#           {
#             "text": "Wookiee",
#             "dbpedia": "http://dbpedia.org/resource/Wookiee",
#             "relevance": 0.413006,
#             "yago": "http://yago-knowledge.org/resource/Wookiee",
#             "freebase": "http://rdf.freebase.com/ns/m.012wm5",
#             "website": "http://www.starwars.com/databank/species/wookiee/"
#           },
#           {
#             "yago": "http://yago-knowledge.org/resource/Princess_Leia_Organa",
#             "text": "Princess Leia Organa",
#             "dbpedia": "http://dbpedia.org/resource/Princess_Leia_Organa",
#             "relevance": 0.404361
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.03_5s0",
#             "text": "Palpatine",
#             "dbpedia": "http://dbpedia.org/resource/Palpatine",
#             "relevance": 0.394821,
#             "yago": "http://yago-knowledge.org/resource/Palpatine"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0nr1k",
#             "text": "Rebel Alliance",
#             "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#             "relevance": 0.378067,
#             "yago": "http://yago-knowledge.org/resource/Rebel_Alliance"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.05dk77",
#             "text": "Tantive IV",
#             "dbpedia": "http://dbpedia.org/resource/Tantive_IV",
#             "relevance": 0.369358,
#             "yago": "http://yago-knowledge.org/resource/Tantive_IV"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0fjms",
#             "text": "Jabba the Hutt",
#             "dbpedia": "http://dbpedia.org/resource/Jabba_the_Hutt",
#             "relevance": 0.311741,
#             "yago": "http://yago-knowledge.org/resource/Jabba_the_Hutt"
#           },
#           {
#             "text": "Star Wars characters",
#             "dbpedia": "http://dbpedia.org/resource/Star_Wars_characters",
#             "relevance": 0.30238
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0dfw0",
#             "text": "Star Wars Episode II: Attack of the Clones",
#             "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_II:_Attack_of_the_Clones",
#             "relevance": 0.294884
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0f325",
#             "text": "Death Star",
#             "dbpedia": "http://dbpedia.org/resource/Death_Star",
#             "relevance": 0.287127,
#             "yago": "http://yago-knowledge.org/resource/Death_Star"
#           },
#           {
#             "yago": "http://yago-knowledge.org/resource/Anakin_Skywalker",
#             "text": "Anakin Skywalker",
#             "dbpedia": "http://dbpedia.org/resource/Anakin_Skywalker",
#             "relevance": 0.264327
#           },
#           {
#             "text": "1977 introductions",
#             "dbpedia": "http://dbpedia.org/resource/1977_introductions",
#             "relevance": 0.260489
#           },
#           {
#             "yago": "http://yago-knowledge.org/resource/Anakin_Solo",
#             "text": "Anakin Solo",
#             "dbpedia": "http://dbpedia.org/resource/Anakin_Solo",
#             "relevance": 0.259341
#           },
#           {
#             "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_I:_The_Phantom_Menace",
#             "text": "Star Wars Episode I: The Phantom Menace",
#             "website": "http://www.starwars.com/movies/episode-i/",
#             "relevance": 0.254888,
#             "freebase": "http://rdf.freebase.com/ns/m.0ddt_"
#           },
#           {
#             "freebase": "http://rdf.freebase.com/ns/m.0g_tb",
#             "text": "Yoda",
#             "dbpedia": "http://dbpedia.org/resource/Yoda",
#             "relevance": 0.25047,
#             "yago": "http://yago-knowledge.org/resource/Yoda"
#           },
#           {
#             "text": "Transformers",
#             "opencyc": "http://sw.opencyc.org/concept/Mx4rv7_gCpwpEbGdrcN5Y29ycA",
#             "dbpedia": "http://dbpedia.org/resource/Transformers_(toy_line)",
#             "relevance": 0.230642,
#             "yago": "http://yago-knowledge.org/resource/Transformers_(toy_line)",
#             "freebase": "http://rdf.freebase.com/ns/m.0191pn",
#             "website": "http://www.transformers.com/"
#           },
#           {
#             "text": "Rebel Dawn",
#             "dbpedia": "http://dbpedia.org/resource/Rebel_Dawn",
#             "relevance": 0.219181,
#             "yago": "http://yago-knowledge.org/resource/Rebel_Dawn",
#             "freebase": "http://rdf.freebase.com/ns/m.0cq1f5",
#             "website": "http://cargobay.starwars.com/webapps/cargobay/item-detail/631"
#           }
#         ],
#         "keywords": [
#           {
#             "sentiment": {
#               "type": "positive",
#               "score": 0.456493,
#               "mixed": false
#             },
#             "text": "Obi-Wan invites Luke",
#             "relevance": 0.985722
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "Obi-Wan views Leia",
#             "relevance": 0.985631
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "smuggler Han Solo",
#             "relevance": 0.79731
#           },
#           {
#             "sentiment": {
#               "type": "positive",
#               "score": 0.456493,
#               "mixed": false
#             },
#             "text": "Alderaan",
#             "relevance": 0.627846
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "Wookiee first mate",
#             "relevance": 0.587261
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.398446,
#               "mixed": false
#             },
#             "text": "Imperial stormtroopers",
#             "relevance": 0.568236
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "Death Star",
#             "relevance": 0.538165
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "Millennium Falcon",
#             "relevance": 0.530428
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "home planet",
#             "relevance": 0.526118
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.398446,
#               "mixed": false
#             },
#             "text": "C-3PO",
#             "relevance": 0.39422
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.398446,
#               "mixed": false
#             },
#             "text": "R2-D2",
#             "relevance": 0.380492
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "Chewbacca",
#             "relevance": 0.378233
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.398446,
#               "mixed": false
#             },
#             "text": "aunt",
#             "relevance": 0.365241
#           },
#           {
#             "sentiment": {
#               "type": "negative",
#               "score": -0.398446,
#               "mixed": false
#             },
#             "text": "uncle",
#             "relevance": 0.354024
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "father",
#             "relevance": 0.350871
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "text": "analysis",
#             "relevance": 0.338317
#           },
#           {
#             "sentiment": {
#               "type": "positive",
#               "score": 0.456493,
#               "mixed": false
#             },
#             "text": "ways",
#             "relevance": 0.33502
#           },
#           {
#             "sentiment": {
#               "type": "positive",
#               "score": 0.456493,
#               "mixed": false
#             },
#             "text": "Force",
#             "relevance": 0.334911
#           }
#         ],
#         "language": "english",
#         "entities": [
#           {
#             "sentiment": {
#               "type": "positive",
#               "score": 0.456493,
#               "mixed": false
#             },
#             "type": "City",
#             "text": "Alderaan",
#             "count": 3,
#             "relevance": 0.809345
#           },
#           {
#             "sentiment": {
#               "type": "positive",
#               "score": 0.127858,
#               "mixed": true
#             },
#             "type": "Person",
#             "text": "Luke",
#             "count": 4,
#             "relevance": 0.572945
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "type": "Person",
#             "text": "Obi-Wan",
#             "count": 1,
#             "relevance": 0.448136
#           },
#           {
#             "sentiment": {
#               "type": "neutral",
#               "mixed": false
#             },
#             "type": "Person",
#             "text": "Wookiee",
#             "count": 1,
#             "relevance": 0.243511
#           }
#         ],
#         "docSentiment": {
#           "type": "positive",
#           "score": 0.4872,
#           "mixed": false
#         },
#         "status": "OK"
#       },
#       "id": "41606653-34cd-4c97-b2e8-e20cd0243ed5",
#       "extracted_metadata": {
#         "filename": "tmpfile",
#         "file_type": "json",
#         "sha1": "f583807ace9a1c8346ff1df285eb63bb651f0e46"
#       },
#       "metadata": {
#         "title": "Star Wars: Episode IV - A New Hope"
#       }
#     }
#   ],
#   "matching_results": 336,
#   "aggregations": [
#     {
#       "path": "enriched_text.entities",
#       "type": "nested",
#       "matching_results": 2520,
#       "aggregations": [
#         {
#           "type": "filter",
#           "match": "enriched_text.entities.type::Facility",
#           "aggregations": [
#             {
#               "type": "term",
#               "field": "enriched_text.entities.text",
#               "results": [
#                 {
#                   "matching_results": 16,
#                   "key": "Grand Moff Tarkin"
#                 },
#                 {
#                   "matching_results": 8,
#                   "key": "Galactic Empire"
#                 },
#                 {
#                   "matching_results": 8,
#                   "key": "Imperial shuttle"
#                 },
#                 {
#                   "matching_results": 8,
#                   "key": "Jabba's palace"
#                 },
#                 {
#                   "matching_results": 8,
#                   "key": "Jedi Temple"
#                 }
#               ]
#             }
#           ],
#           "matching_results": 48
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# Change the above query and see what results you get! Try to find one that returns relevant results, and keep that (along with the output) for review.
#
# > See [Query building reference](https://www.ibm.com/watson/developercloud/doc/discovery/query-reference.html) for descriptions of all possible parameters, operators and aggregations. You can also choose to build the query using the web interface (click the "Story Chunks" collection to query it), and then reproduce the query here.
#
# Then answer the questions below:
#
# **Q**: What query did you try? Express it in plain words below.
#
# **A**: I tried a query that returns identified facilities(places) in the text. In that I'm requesting entities.type to be "Facility", and aggregates results by entity text.
#
#
# **Q**: What answer did you get back from Watson? You only need to mention the relevant snippet of text from the paragraph(s) returned.
#
# **A**: Returned results identified 18 matches, 5 unique ones: Grand Moff Tarkin, Jedi Temple, Jabba's palace, Imperial shuttle, and Galactic Empire. Within the paragraphs returned other entities and their types are also returned. Below is the returned results:
#
#
#   "aggregations": [
#
#       "path": "enriched_text.entities",
#       "aggregations": [
#
#           "aggregations": [
#
#               "field": "enriched_text.entities.text",
#               "type": "term",
#               "results": [
#
#                   "key": "Grand Moff Tarkin",
#                   "matching_results": 12
#
#
#                   "key": "Galactic Empire",
#                   "matching_results": 6
#
#
#                   "key": "Imperial shuttle",
#                   "matching_results": 6
#
#                   "key": "Jabba's palace",
#                   "matching_results": 6
#
#                   "key": "Jedi Temple",
#                   "matching_results": 6

# %% [markdown]
# ## 3. Parse natural language questions
#
# In order to understand questions posed in natural language, we'll use another Watson service called [Conversation](https://www.ibm.com/watson/developercloud/doc/conversation/index.html). It can be used to design conversational agents or _chatbots_ that exhibit complex behavior, but for the purpose of this project, we'll only use it to parse certain kinds of queries.
#
# ### Create a Conversation service instance
#
# Just like you did for the Discovery service, create an instance of the Conversation service. Then launch the associated tool from the service dashboard.
#
# <img src="images/conversation-tooling.png" alt="Conversation service - Tool homepage" width="800" />
#
# A _workspace_ allows you to keep all the items you need for a particular application in one place, just like an _environment_ in case of the Discovery service. Create one called "Bookworm" with a suitable description, such as "I know a lot of stories. Ask me a question!"
#
# <img src="images/conversation-workspace.png" alt="Conversation service - Blank workspace" width="800" />
#
# This should open up a blank workspace, where you can add intents, define the entities you want the agent to idenitfy and structure the overall dialog.
#
# ### Add intents
#
# An _intent_ is the goal or purpose of a user's input. Create a set of intents (at least 3) that capture the different kinds of questions that you want the system to answer, e.g. _who_, _what_ and _where_. Along with each intent, add a list of user examples or _utterances_ that map to that intent.
#
# For instance, you could enter the following examples for the _where_ intent:
#
# - Where is the Jedi temple located?
# - Where was Luke born?
#
# The Conversation service recommends at least 5 examples for each intent so that Watson learns how to recognize it. These don't have to be very precise, but more examples the better.
#
# <img src="images/conversation-intents.png" alt="Conversation service - Intents listed" width="800" />
#
# Feel free to create your own intents, based on the kinds of questions you want the system to answer, e.g. "How many ...", "What are the most common ..." etc. Each intent will need to be mapped to an appropriate query.
#
# > See [**Defining intents**](https://www.ibm.com/watson/developercloud/doc/conversation/intents.html) for a helpful video and further instructions.
#
# **Q**: What intents did you add to the Conversation service instance?
#
# **A**: episode-summary, who_killed, who is
#
#
#
# **Q**: Pick one of these intents, and list at least 5 examples for the intent that you entered.
#
# **A**: Intent: who_killed --- Examples: Who murdered him? How did Leia die? Who killed Luke? Is Luke alive? What was Jango cause of death?
#
#
#
#
#
# ### Add entities
#
# Once you have your intents set, let's tell the service what entities we want it to identify. One way to do this is using the tool interface, and entering them one-by-one.
#
# > Go to [**Defining entities**](https://www.ibm.com/watson/developercloud/doc/conversation/entities.html) to see how that is done.
#
# But that can be tedious! So let's refer back to the entities that the Discovery service identified, and load them in programmatically.
#
# As before, let's connect to the Conversation service first. Remember to enter your service credentials below.

# %%
# Connect to the Conversation service instance
# TODO: Enter your username and password from the Service Credentials tab in service-credentials.json
conversation_creds = helper.fetch_credentials('conversation')
conversation = watson_developer_cloud.ConversationV1(
    version='2017-02-03',
    username=conversation_creds['username'],
    password=conversation_creds['password'])

# %% [markdown]
# Fetch the workspace you just created called "Bookworm".

# %%
wrk, wrk_id = helper.fetch_object(conversation, "workspace", "aind")
print(json.dumps(wrk, indent=2))
# Out:
# Found workspace: aind (3293719e-9d47-48af-93de-7c420ab6da25)
# {
#   "created": "2017-06-24T02:44:51.708Z",
#   "workspace_id": "3293719e-9d47-48af-93de-7c420ab6da25",
#   "updated": "2017-06-28T16:22:14.238Z",
#   "description": "I know a lot of stories. Ask me a question!\"",
#   "status": "Available",
#   "metadata": null,
#   "name": "aind",
#   "language": "en"
# }

# %% [markdown]
# Collect all the entities from the Discovery service collection.

# %%
# Get all the entities from the collection and group them by type
response = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "return": "enriched_text.entities.type,enriched_text.entities.text"
    })

# Group individual entities by type ("Person", "Location", etc.)
entities_by_type = {}
for document in response["results"]:
    for entity in document["enriched_text"]["entities"]:
        if entity["type"] not in entities_by_type:
            entities_by_type[entity["type"]] = set()
        entities_by_type[entity["type"]].add(entity["text"])

# Ignore case to avoid duplicates
for entity_type in entities_by_type:
    entities_by_type[entity_type] = {
        e.lower(): e for e in entities_by_type[entity_type]
    }.values()

# Restructure for loading into Conversation workspace
entities_grouped = [{
    "entity": entity_type,
    "values": [{"value": entity} for entity in entities]}
        for entity_type, entities in entities_by_type.items()]
entities_grouped
# Out:
# [{'entity': 'JobTitle',
#   'values': [{'value': 'representative'}, {'value': 'officer'}]},
#  {'entity': 'Person',
#   'values': [{'value': 'Padm̩'},
#    {'value': 'Boba'},
#    {'value': 'Anakin Skywalker'},
#    {'value': 'Shmi'},
#    {'value': 'Beru Lars'},
#    {'value': 'Darth Sidious'},
#    {'value': 'Cliegg Lars'},
#    {'value': 'Obi-Wan Kenobi'},
#    {'value': 'Senator Padm̩ Amidala'},
#    {'value': 'Supreme Chancellor Palpatine'},
#    {'value': 'Mace Windu'},
#    {'value': 'Geonosis'},
#    {'value': 'Vader'},
#    {'value': 'Darth Vader'},
#    {'value': 'Owen'},
#    {'value': 'Count Dooku'},
#    {'value': 'Luke Skywalker'},
#    {'value': 'Palpatine'},
#    {'value': 'Yoda'},
#    {'value': 'Jango Fett'},
#    {'value': 'Organa'},
#    {'value': 'Viceroy Nute Gunray'},
#    {'value': 'Anakin'},
#    {'value': 'Leia'},
#    {'value': 'Polis Massa'},
#    {'value': 'Princess Leia'},
#    {'value': 'Luke'},
#    {'value': 'Mustafar'},
#    {'value': 'Wookiee'},
#    {'value': 'Han'},
#    {'value': 'Zam Wesell'},
#    {'value': 'Obi-Wan'}]},
#  {'entity': 'Organization',
#   'values': [{'value': 'Jedi Council'},
#    {'value': 'Rebel Alliance'},
#    {'value': 'Rebel assault squadron'},
#    {'value': 'Galactic Republic'},
#    {'value': 'Senate'},
#    {'value': 'Tusken Raiders'},
#    {'value': 'Rebels'},
#    {'value': 'droid army'},
#    {'value': 'Trade Federation'}]},
#  {'entity': 'Quantity', 'values': [{'value': 'Ten years'}]},
#  {'entity': 'Facility',
#   'values': [{'value': 'Grand Moff Tarkin'}, {'value': 'Jedi Temple'}]},
#  {'entity': 'FieldTerminology', 'values': [{'value': 'civil war'}]},
#  {'entity': 'City',
#   'values': [{'value': 'Geonosis'},
#    {'value': 'Mustafar'},
#    {'value': 'Tatooine'},
#    {'value': 'Kashyyyk'},
#    {'value': 'Alderaan'},
#    {'value': 'Tusken'},
#    {'value': 'Coruscant'}]},
#  {'entity': 'Company',
#   'values': [{'value': 'Jawa traders'}, {'value': 'Falcon'}]}]

# %% [markdown]
# Update the workspace with these entities and verify that have been added correctly.

# %%
# Add these grouped entities to the Conversation workspace
conversation.update_workspace(workspace_id=wrk_id, entities=entities_grouped)

workspace_details = conversation.get_workspace(workspace_id=wrk_id, export=True)
print(json.dumps(workspace_details["entities"], indent=2))
# Out:
# [
#   {
#     "open_list": null,
#     "values": [
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Geonosis",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Mustafar",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Tatooine",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Kashyyyk",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Alderaan",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Tusken",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Coruscant",
#         "created": "2017-06-30T21:53:18.921Z"
#       }
#     ],
#     "entity": "City",
#     "updated": "2017-06-30T21:53:18.921Z",
#     "type": null,
#     "description": null,
#     "source": null,
#     "created": "2017-06-30T21:53:18.921Z"
#   },
#   {
#     "open_list": null,
#     "values": [
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Ten years",
#         "created": "2017-06-30T21:53:18.921Z"
#       }
#     ],
#     "entity": "Quantity",
#     "updated": "2017-06-30T21:53:18.921Z",
#     "type": null,
#     "description": null,
#     "source": null,
#     "created": "2017-06-30T21:53:18.921Z"
#   },
#   {
#     "open_list": null,
#     "values": [
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Jedi Council",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Rebel Alliance",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Rebel assault squadron",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Galactic Republic",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Senate",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Tusken Raiders",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Rebels",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "droid army",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Trade Federation",
#         "created": "2017-06-30T21:53:18.921Z"
#       }
#     ],
#     "entity": "Organization",
#     "updated": "2017-06-30T21:53:18.921Z",
#     "type": null,
#     "description": null,
#     "source": null,
#     "created": "2017-06-30T21:53:18.921Z"
#   },
#   {
#     "open_list": null,
#     "values": [
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "civil war",
#         "created": "2017-06-30T21:53:18.921Z"
#       }
#     ],
#     "entity": "FieldTerminology",
#     "updated": "2017-06-30T21:53:18.921Z",
#     "type": null,
#     "description": null,
#     "source": null,
#     "created": "2017-06-30T21:53:18.921Z"
#   },
#   {
#     "open_list": null,
#     "values": [
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "representative",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "officer",
#         "created": "2017-06-30T21:53:18.921Z"
#       }
#     ],
#     "entity": "JobTitle",
#     "updated": "2017-06-30T21:53:18.921Z",
#     "type": null,
#     "description": null,
#     "source": null,
#     "created": "2017-06-30T21:53:18.921Z"
#   },
#   {
#     "open_list": null,
#     "values": [
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Jawa traders",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Falcon",
#         "created": "2017-06-30T21:53:18.921Z"
#       }
#     ],
#     "entity": "Company",
#     "updated": "2017-06-30T21:53:18.921Z",
#     "type": null,
#     "description": null,
#     "source": null,
#     "created": "2017-06-30T21:53:18.921Z"
#   },
#   {
#     "open_list": null,
#     "values": [
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Grand Moff Tarkin",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Jedi Temple",
#         "created": "2017-06-30T21:53:18.921Z"
#       }
#     ],
#     "entity": "Facility",
#     "updated": "2017-06-30T21:53:18.921Z",
#     "type": null,
#     "description": null,
#     "source": null,
#     "created": "2017-06-30T21:53:18.921Z"
#   },
#   {
#     "open_list": null,
#     "values": [
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Padm\u00c3\u00a9",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Boba",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Anakin Skywalker",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Shmi",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Beru Lars",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Darth Sidious",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Cliegg Lars",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Obi-Wan Kenobi",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Senator Padm\u00c3\u00a9 Amidala",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Supreme Chancellor Palpatine",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Mace Windu",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Geonosis",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Vader",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Darth Vader",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Owen",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Count Dooku",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Luke Skywalker",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Palpatine",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Yoda",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Jango Fett",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Organa",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Viceroy Nute Gunray",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Anakin",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Leia",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Polis Massa",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Princess Leia",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Luke",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Mustafar",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Wookiee",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Han",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Zam Wesell",
#         "created": "2017-06-30T21:53:18.921Z"
#       },
#       {
#         "updated": "2017-06-30T21:53:18.921Z",
#         "synonyms": [],
#         "metadata": null,
#         "value": "Obi-Wan",
#         "created": "2017-06-30T21:53:18.921Z"
#       }
#     ],
#     "entity": "Person",
#     "updated": "2017-06-30T21:53:18.921Z",
#     "type": null,
#     "description": null,
#     "source": null,
#     "created": "2017-06-30T21:53:18.921Z"
#   }
# ]

# %% [markdown]
# _**Note**: Ensure that at least 3 entity types, with at least 1 example entity each have been added._
#
# Here is what the list of entities should look like through the Conversation tool.
#
# <img src="images/conversation-entities.png" alt="Conversation service - Entities listed" width="800" />
#
# **Q**: Name 3 entity types that were added, with at least 1 example entity each (e.g. entity type: _City_, example: _Los Angeles_).
#
# **A**: City: Kashyyyk, Alderaan, Geonosis, Tatooine, Coruscant, Tusken, Mustafar  ----  Company: Falcon, Jawa traders ---- Organization: enate, Rebel assault squadron, droid army, Jedi Council, Galactic Republic, Trade Federation, Rebel Alliance, Rebels, Tusken Raiders

# %% [markdown]
# ### Design dialog flow
#
# As a final step in creating the Conversation interface, let's design a typical dialog with a user. The most intuitive way to do this is to use the Dialog tab in the tool. Here, you can add _nodes_ that capture different stages in the dialog flow, and connect them in a meaningful way.
#
# Go ahead and add at least 3 dialog nodes. Specify the triggers in terms of the intents and entities that you'd like to match, and an optional intermediate response like "Let me find that out for you." The actual response will be fetched by querying the Discovery service.
#
# Here is what the dialog nodes should look like.
#
# <img src="images/conversation-dialog_nodes.png" alt="Conversation service - Dialog nodes" width="640" />
#
# **Q**: Specify 3 dialog nodes you added, along with the trigger (intent and/or entities) for each.
#
# **A**: Person node, trigger #who_is, response "Let me find this person for you." --- who-killed node, trigger #who killed, response "Checking on that..." --- Reason episode-summary, trigger #episode summary intent + episode number enitity, response "Let me see..."

# %% [markdown]
# ### Test dialog
#
# Let's run through a test dialog to demonstrate how the system transitions to one of the nodes you defined above.

# %%
# Testing the dialog flow

# Start conversation with a blank message
results = conversation.message(workspace_id=wrk_id, message_input={})
context = results["context"]

# Then ask a sample question
question= "Who is Luke's father?"
results = conversation.message(workspace_id=wrk_id, message_input={
    "text": question,
    "context": context
})
print(json.dumps(results, indent=2))
# Out:
# {
#   "context": {
#     "conversation_id": "065a910a-410a-4387-8926-21ff245e1bb0",
#     "system": {
#       "branch_exited_reason": "completed",
#       "branch_exited": true,
#       "dialog_turn_counter": 1,
#       "_node_output_map": {
#         "Anything else": [
#           0
#         ]
#       },
#       "dialog_stack": [
#         {
#           "dialog_node": "root"
#         }
#       ],
#       "dialog_request_counter": 1
#     }
#   },
#   "input": {
#     "context": {
#       "conversation_id": "7d0d8e3a-8000-4109-8624-2fd13219e8a2",
#       "system": {
#         "dialog_request_counter": 1,
#         "branch_exited": true,
#         "dialog_turn_counter": 1,
#         "_node_output_map": {
#           "Welcome": [
#             0
#           ]
#         },
#         "dialog_stack": [
#           {
#             "dialog_node": "root"
#           }
#         ],
#         "branch_exited_reason": "completed"
#       }
#     },
#     "text": "Who is Luke's father?"
#   },
#   "entities": [
#     {
#       "confidence": 1,
#       "location": [
#         7,
#         11
#       ],
#       "value": "Luke",
#       "entity": "Person"
#     }
#   ],
#   "intents": [
#     {
#       "confidence": 0.911970317363739,
#       "intent": "who_is"
#     }
#   ],
#   "output": {
#     "log_messages": [],
#     "text": [
#       "I didn't understand. You can try rephrasing."
#     ],
#     "nodes_visited": [
#       "Anything else"
#     ]
#   }
# }

# %% [markdown]
# ## 4. Query document collection to fetch answers
#
# The Discovery service includes a simple mechanism to make queries against your enriched collection of documents. But you have a lot of control over what fields are searched, how results are aggregated and values are returned.
#
# ### Process sample question
#
# Choose a sample nautal language question to ask, and run it through the Conversation service, just like you did above when testing dialog flow.

# %%
# TODO: Run a sample question through Conversation service

question= "Is Han alive?"
#question = "tell me something about Han"
#question = "What did Luke do in episode 4?"
results = conversation.message(workspace_id=wrk_id, message_input={
    "text": question,
    "context": context
})
print(json.dumps(results, indent=2))
# Out:
# {
#   "context": {
#     "conversation_id": "4a88b5a0-c836-464c-9aed-51f1dafb841c",
#     "system": {
#       "branch_exited_reason": "completed",
#       "branch_exited": true,
#       "dialog_turn_counter": 1,
#       "_node_output_map": {
#         "who_killed": [
#           0
#         ]
#       },
#       "dialog_stack": [
#         {
#           "dialog_node": "root"
#         }
#       ],
#       "dialog_request_counter": 1
#     }
#   },
#   "input": {
#     "context": {
#       "conversation_id": "7d0d8e3a-8000-4109-8624-2fd13219e8a2",
#       "system": {
#         "dialog_request_counter": 1,
#         "branch_exited": true,
#         "dialog_turn_counter": 1,
#         "_node_output_map": {
#           "Welcome": [
#             0
#           ]
#         },
#         "dialog_stack": [
#           {
#             "dialog_node": "root"
#           }
#         ],
#         "branch_exited_reason": "completed"
#       }
#     },
#     "text": "Is Han alive?"
#   },
#   "entities": [
#     {
#       "confidence": 1,
#       "location": [
#         3,
#         6
#       ],
#       "value": "Han",
#       "entity": "Person"
#     }
#   ],
#   "intents": [
#     {
#       "confidence": 0.9328420758247375,
#       "intent": "who_killed"
#     }
#   ],
#   "output": {
#     "log_messages": [],
#     "text": [
#       "Checking on that..."
#     ],
#     "nodes_visited": [
#       "who_killed"
#     ]
#   }
# }

# %% [markdown]
# Now extract the intent and entities identified in the question, and optionally what dialog node was triggered (in case you need it later to customize your response). Some sample code is provided below, but you may need to modify it.

# %%
# TODO: Identify the intent(s) the user expressed (typically a single one)
query_intents = [intent["intent"] for intent in results["intents"]]
print("Intent(s):", query_intents)

# TODO: Extract the entities found in the question text
query_entities = [(entity["value"], entity["entity"]) for entity in results["entities"]]
print("Entities:", query_entities)

# TODO: (optional) Find out what dialog node was triggered
nodes_triggered = [node for node in results["output"]["nodes_visited"]]
print("Node(s) Triggered:", nodes_triggered)
# Out:
# Intent(s): ['who_killed']
# Entities: [('Han', 'Person')]
# Node(s) Triggered: ['who_killed']

# %% [markdown]
# ### Query the collection
#
# Design a query based on the information extracted above, and run it against the document collection. The sample query provided below simple looks for all the entities in the raw `text` field. Modify it to suit your needs.
#
# Take a look at the [API Reference](https://www.ibm.com/watson/developercloud/discovery/api/v1/?python#query-collection) to learn more about the query options available, and for more guidance see this [documentation page](https://www.ibm.com/watson/developercloud/doc/discovery/using.html).
#
# _**Note**: You may want to design different queries based on the intent / dialog node that was triggered._

# %%
# TODO: Query the Discovery service based on the intent and entities

if query_intents[0] == 'episode-summary':

    person = [entity[0] for entity in query_entities if entity[1] == 'Person'][0]
    episode = [entity[0] for entity in query_entities if entity[1] == 'Episode'][0]
    results = discovery.query(environment_id=env_id, collection_id=col_id,
        query_options={
            "query": "metadata.title:{0}, enriched_text.relations.subject.text:{1}".format(episode, person)
            #"return": "text"
        })

    b = [sentence for result in results["results"] for sentence in result["enriched_text"]["relations"] if ("subject" in sentence.keys())]
    bb = [sentence for sentence in b if "entities" in sentence["subject"].keys()]
    c = [sentence for result in results["results"] for sentence in result["enriched_text"]["relations"] if ("object" in sentence.keys())]
    cc = [sentence for sentence in c if "entities" in sentence["object"].keys()]
    d = [sentence["sentence"] for sentence in bb for item in sentence["subject"]["entities"] if item["text"] == person]
    e = [sentence["sentence"] for sentence in cc for item in sentence["object"]["entities"] if item["text"] == person]
    d = list(set(d))
    e = list(set(e))
    if d:
        for item in d:
            print(item)
    if e:
        for item in e:
            print(item)
    elif not d and not e:
        print("I could not find relevant information")
    #print("{0} was the leader of {1}.".format(d[0], query_entities[0][0]))
    #print(json.dumps(results, indent=2))



if query_intents[0] == 'who_is':

    results = discovery.query(environment_id=env_id, collection_id=col_id,
        query_options={
            "query": "enriched_text.relations.subject.entities.type::Person, enriched_text.relations.action.verb.text::be, enriched_text.relations.subject.entities.text::{}".format(query_entities[0][0])
        })

    b = [sentence for result in results["results"] for sentence in result["enriched_text"]["relations"] if ("entities" in sentence["subject"].keys() and sentence["action"]["verb"]["text"] == "be")]
    c = [sentence["sentence"] for sentence in b for item in sentence["subject"]["entities"] if (item["text"] == query_entities[0][0] and "entities" in sentence["object"].keys())]
    print("A fact about {0}: {1}.".format(query_entities[0][0], c[0]))

if query_intents[0] == 'who_killed':

    results = discovery.query(environment_id=env_id, collection_id=col_id,
        query_options={
            #"aggregation": "filter(enriched_text.relations.subject.entities.type::Person).filter(enriched_text.relations.action.lemmatized:kill).filter(enriched_text.relations.object.entities.text::Jango Fett)",
            "query": "enriched_text.relations.action.lemmatized:kill, enriched_text.relations.object.entities.text::{}".format(query_entities[0][0])
            #"return": "metadata.title, enriched_text.relations"
        })

    b = [sentence for result in results["results"] for sentence in result["enriched_text"]["relations"] if ("object" in sentence.keys() and "entities" in sentence["object"].keys() and sentence["action"]["verb"]["text"] == "kill")]
    c = [sentence["subject"]["entities"][0]["text"] for sentence in b for item in sentence["object"]["entities"] if item["text"] == query_entities[0][0]]
    print("{0} killed {1}.".format(c[0], query_entities[0][0]))
# Out:
# Ren killed Han.

# %% [markdown]
# ### Process returned results
#
# If you properly structure the query, Watson is able to do a pretty good job of finding the relevant information. But the result returned is a JSON object. Now your task is to convert that result into an appropriate response that best addresses the original natural language question that was asked.
#
# E.g. if the question was "Who saved Han Solo from Jabba the Hutt?" the answer should ideally just be "The Rebels" and not the entire paragraph describing Han Solo's rescue. But that can be a backup response if you cannot be more specific.
#
# _**Note**: You may have to go back to the previous step and modify the query, especially what you want the Discovery service to return, and this may depend on the intent / dialog node triggered. E.g. study the different parts of a "relation" structure to see how you might construct queries to match them._

# %%
# TODO: Process returned results and compose an appropriate response

# Done in above cell

# %% [markdown]
# ## 5. Reflections
#
# **Q**: Now that you have gone through this exercise of designing a system that uses two IBM Watson services, what did you learn? What were some of the strengths and weaknesses of this approach?
#
# **A**:
# Pros: Watson discovery service can extract meaningful relations and concepts from the text with little effort. It's relatively easy to query the collection of documents to extract this information. Conversation service can effectively understand user's intent from handful of examples provided and generlize well.
#
# Cons: Disovery queries are only helpful if you know exactly or partially what you look for otherwise it could be confusing. Whit aggregating queries sometimes too much information is returned. With conversation service, most of user's intent has to be hand-coded in the system which is not the best possible way of doing this. WHat if an intent is missing or what if enough examples for each intent was not provided, this might result in mis-classifieng some ways of users conveyoring the same intent.
#
#
# ## (Optional) Extensions
#
# We have provided a set of sample data files containing Star Wars plot summaries. But as mentioned before, you are free to use your own dataset. In fact, a larger dataset maybe more suitable for use with IBM Watson's NLP services. If you used your own dataset, answer the following questions.
#
# **Q**: What dataset did you use, and in what ways is it different from the sample files provided?
#
# **A**:
#
#
# **Q**: Either include your dataset in the .zip file or repository you submit, or provide clear instructions on how to obtain the dataset, so that your reviewer can run your notebook or inspect the data to verify your results.
#
# **A**:
#
#
# _You can also design a web-based application that utilizes these services and deploy that on Bluemix! If you do, please share with your instructors and peers._
